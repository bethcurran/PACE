# %%
import traceback
import warnings

from io import StringIO
import ee
import time
import os
from glob import glob
from typing import Optional, Callable, List, Tuple
from shapely.geometry import mapping, Polygon
import numpy as np
import geopandas as gpd
import pandas as pd
import fsspec
from datetime import datetime, timezone
import math
import json

from ml4floods.data import ee_download, utils

# %% [markdown]
# # Calling some functions

# %% [markdown]
# Removed the full function call and used the following instead.

# %%
get_count_function = ee_download.get_count_function

# %%
get_landsat_collection = ee_download.get_landsat_collection

# %%
collection_mosaic_day = ee_download.collection_mosaic_day

# %%
BANDS_NAMES = ee_download.BANDS_NAMES

# %% [markdown]
# Calling the aoi file

# %% [markdown]
# # Reading the geojson file

# %%
sydney_aoi= gpd.read_file('2022-07-21_aois.geojson')

# %%
sydney_aoi
# Out:
#     aoi_code                                           geometry
# 0      AOI01  POLYGON ((147.09960 -31.24462, 147.30960 -31.2...
# 1      AOI01  POLYGON ((147.09960 -31.24462, 147.30960 -31.2...
# 2      AOI02  POLYGON ((147.09960 -31.04462, 147.30960 -31.0...
# 3      AOI02  POLYGON ((147.09960 -31.04462, 147.30960 -31.0...
# 4    AOI0289  POLYGON ((147.49960 -32.44461, 147.70960 -32.4...
# ..       ...                                                ...
# 476    AOI97  POLYGON ((150.29960 -34.24462, 150.50960 -34.2...
# 477    AOI98  POLYGON ((150.29960 -34.04462, 150.50960 -34.0...
# 478    AOI98  POLYGON ((150.29960 -34.04462, 150.50960 -34.0...
# 479    AOI99  POLYGON ((150.29960 -33.84462, 150.50960 -33.8...
# 480    AOI99  POLYGON ((150.29960 -33.84462, 150.50960 -33.8...
#
# [481 rows x 2 columns]

# %%
sydney_aoi.geometry
# Out:
# 0      POLYGON ((147.09960 -31.24462, 147.30960 -31.2...
# 1      POLYGON ((147.09960 -31.24462, 147.30960 -31.2...
# 2      POLYGON ((147.09960 -31.04462, 147.30960 -31.0...
# 3      POLYGON ((147.09960 -31.04462, 147.30960 -31.0...
# 4      POLYGON ((147.49960 -32.44461, 147.70960 -32.4...
#                              ...
# 476    POLYGON ((150.29960 -34.24462, 150.50960 -34.2...
# 477    POLYGON ((150.29960 -34.04462, 150.50960 -34.0...
# 478    POLYGON ((150.29960 -34.04462, 150.50960 -34.0...
# 479    POLYGON ((150.29960 -33.84462, 150.50960 -33.8...
# 480    POLYGON ((150.29960 -33.84462, 150.50960 -33.8...
# Name: geometry, Length: 481, dtype: geometry

# %% [markdown]
# Getting the bounds from a single polygon

# %%
test_bounds= sydney_aoi.geometry[0].bounds
test_bounds
# Out:
# (147.09959654580408,
#  -31.244618412374592,
#  147.30959654580408,
#  -31.03461841237459)

# %% [markdown]
# # Sorting the dates

# %% [markdown]
# Converting standard date format into a datetime objectget_landsat_collection(date_start= , date_end= , bounds= test_bounds)

# %%
date_string_start = '02/08/21'
date_string_end = '03/09/21'
datetime_start= datetime.strptime(date_string_start, '%d/%m/%y')
datetime_end= datetime.strptime(date_string_end, '%d/%m/%y')
datetime_start
# Out:
# datetime.datetime(2021, 8, 2, 0, 0)

# %%
date_range = ('02/08/21', '03/09/21')

# %%
type(date_range)
# Out:
# tuple

# %%
#Test of datetime function from query notebook

#e.g. date_range = ('dd/mm/yy', 'dd/mm/yy')

def get_datetime(date_range):
    datetime_start= datetime.strptime(date_range[0], '%d/%m/%y')
    datetime_end= datetime.strptime(date_range[1], '%d/%m/%y')
    
    start_year = datetime_start.year
    end_year = datetime_end.year
    
    return datetime_start, datetime_end, start_year, end_year

dates = get_datetime(date_range)

print(dates)
# Out:
# (datetime.datetime(2021, 8, 2, 0, 0), datetime.datetime(2021, 9, 3, 0, 0), 2021, 2021)

# %%
type(dates[0])
# Out:
# datetime.datetime

# %%
print(f'Start datetime: {dates[0]}, end datetime: {dates[1]}')
# Out:
# Start datetime: 2021-08-02 00:00:00, end datetime: 2021-09-03 00:00:00

# %% [markdown]
# # Authenticating `ee`

# %% [markdown]
# First will have to run `earthengine authenticate` in the VM command line / terminal.
#
# **Issue:** Doesn't allow us to authenticate. We get an 'access blocked' message. We checked the GCP API information under APIs and Servicse > Enabled APIs & Services and there are no API credentials (client ID and key). We had a look into what the issue might be and found that we may need to enable 'Google Earth Engine API', but this did nothing.
#
# - Do we need client ID and key for the API to get access?
# - Do we need to open the authentication link  in a VM browser?
# - Any other reasons why the authentication link doesn't work
#
#
# **SOLVED** Cormac suggested to run the following

# %%
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=_ZtJPwq2ZdDHVKQQBx31cPLTjynkQUPWLj05_K3MLpw&tc=480S43G1Efi6DJG0s1fcYVCWHCAXnE0JccuxMSgQhFU&cc=2V8bTeW1oH09kCZAMwRHeSGEv3WOccafKtgBvnAtO1M>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=_ZtJPwq2ZdDHVKQQBx31cPLTjynkQUPWLj05_K3MLpw&tc=480S43G1Efi6DJG0s1fcYVCWHCAXnE0JccuxMSgQhFU&cc=2V8bTeW1oH09kCZAMwRHeSGEv3WOccafKtgBvnAtO1M</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1AdQt8qiM7yWN84JOq0PIKQ55S1EJ2b1USKgagEvwslNOgJFnhxupJo8IMIc
# Successfully saved authorization token.

# %% [markdown]
# Initialise earth engine (ee)

# %%
ee.Initialize()

# %% [markdown]
# # Getting the bounds and getting the images

# %%
type(sydney_aoi.geometry[0].bounds)
# Out:
# tuple

# %%
js = json.loads(sydney_aoi.to_json()) # Converting the aoi to a json and loading the json information, inludes coordinates,
                                        # id for each polygon. Within the dictionary we have a 'featureCollection'
    
bounds = ee.Geometry(ee.FeatureCollection(js).geometry()) # Getting the bounds of the polygons 

type(bounds)
# Out:
# ee.geometry.Geometry

# %% [raw]
# type(js)

# %% [raw]
# js

# %% [raw]
# js['features'][0]['geometry']['coordinates']

# %% [raw]
# sydney_aoi.geometry

# %% [raw]
# bounds

# %%
landsat_imgs = get_landsat_collection(date_start=dates[0], date_end=dates[1] , bounds=bounds)

# %%
type(landsat_imgs)
# Out:
# ee.imagecollection.ImageCollection

# %% [markdown]
# # Checking the properties of the imageCollection

# %% [markdown]
# Checking the size of the image collection

# %% [markdown]
# NOTE: Find date range limits that won't time out

# %% [markdown]
# **Example** from https://developers.google.com/earth-engine/apidocs/ee-imagecollection-size

# %%
col = ee.ImageCollection('LANDSAT/LC08/C02/T1_TOA').filterBounds(ee.Geometry.Point(-90.70, 34.71)).filterDate('2020-01-01', '2021-01-01');

# %%
type(col)
# Out:
# ee.imagecollection.ImageCollection

# %% [markdown]
# [running the below code in this link gives the number of images](https://code.earthengine.google.com/820fcb75a86f86352d4ae1d62c4650fe)

# %% [raw]
# // Note: ee.ImageCollection.size may take a lot of time and memory to run,
# // since it must generate all of the results in order to count them. Large
# // collections and/or complex computations can produce memory limitation
# // errors.
#
# // A Landsat 8 TOA image collection (1 year of images at a specific point).
# var col = ee.ImageCollection('LANDSAT/LC08/C02/T1_TOA')
#   .filterBounds(ee.Geometry.Point(-90.70, 34.71))
#   .filterDate('2020-01-01', '2021-01-01');
#
# // Get the number of images in the collection.
# print('Number of images', col.size());

# %% [markdown]
# **End Example**

# %% [markdown]
# After checking the function `_get_collection()` in the script, I noticed the variable `n_images` which seemed like 'number of images'. Using the same code from the script gives us:

# %%
landsat_imgs.size().getInfo()
# Out:
# 12

# %% [markdown]
# We can see the `CLOUD_SCORE` is contained in
#
# features: [] -> id: 'date', properties: {} -> CLOUD_SCORE

# %%
myDict = landsat_imgs.getInfo()

# %%
len(myDict['features'])
# Out:
# 12

# %%
myDict['features'][0].get('id')
# Out:
# '2021-08-17'

# %%
myDict = landsat_imgs.getInfo()

# %%
myDict['features'][0].get('properties')['CLOUD_COVER']
# Out:
# 3.48

# %%
cloudScore_landsat = np.array([])

for i in range(len(myDict['features'])):
    val = myDict['features'][i].get('properties')['CLOUD_COVER']
    cloudScore_landsat = np.append(cloudScore_landsat, val)
    print(i, val) 


print(f'Mean cloud score is {cloudScore_landsat.mean()}')
# Out:
# 0 3.48
# 1 10.97
# 2 40.43
# 3 76.51
# 4 0.32
# 5 0.05
# 6 54.69
# 7 10.8
# 8 0.02
# 9 14.17
# 10 1.96
# 11 0.01
# Mean cloud score is 17.784166666666668

# %% [markdown]
# Now we need to know what a cloud score looks like and if there are any other properties we want to consider from the imageCollection.

# %% [markdown]
# plot out on a spatial grid.
#
# Each patch may have multiple images with each of the cloud scores.
#
# geopandas table with whichever coordinates used. coords and cloud cover.
# sleep statement after each point to see how the plot is being built.
#
# ---
#
# geoscape query and intersects.
#
# ---
#
# linking the keys for both satellites.

# %% [raw]
# myDict['features'][0].get('properties')

# %% [markdown]
# To access the information, the procses looks like this: `landsat_imgs.getInfo()['features'][my_index].get('properties')['my_feature']`.
#
# getInfo() is a dictionary, so we access the dictionary by calling one of the words in the dictionary being 'features'. This now becomes a list of the different images, so we can index into the image we want. We then use the get() function which again returns a dictionary we can access with one of the words in the dictionary to access the information.

# %% [markdown]
# **Now getting the images for s2. Note, s2 has different properties to landsat**

# %%
get_s2_collection = ee_download.get_s2_collection

# %%
s2_imgs = get_s2_collection(date_start=dates[0], date_end=dates[1] , bounds=bounds)

# %%
s2_imgs.getInfo()['features'][0].get('properties')['CLOUD_COVERAGE_ASSESSMENT']
# Out:
# 10.1582

# %% [markdown]
# Number of images

# %%
s2_imgs.size().getInfo()
# Out:
# 26

# %%
myDict2 = s2_imgs.getInfo()

# %%
cloudScore_s2 = np.array([])

for i in range(s2_imgs.size().getInfo()):
    val = myDict2['features'][i].get('properties')['CLOUD_COVERAGE_ASSESSMENT']
    cloudScore_s2 = np.append(cloudScore_s2, val)
    print(i, val)
    
print(f'Mean cloud score is {cloudScore_s2.mean()}')
# Out:
# 0 10.1582
# 1 18.4946
# 2 19.9737
# 3 57.2791
# 4 69.7648
# 5 0
# 6 1.937
# 7 6.9454
# 8 16.4855
# 9 0
# 10 0
# 11 29.3754
# 12 0
# 13 98.0081
# 14 0
# 15 0
# 16 90.0543
# 17 99.9021
# 18 0
# 19 51.3534
# 20 0
# 21 99.9965
# 22 99.9962
# 23 0.2658
# 24 0
# 25 0
# Mean cloud score is 29.615003846153847

# %% [raw]
# s2_imgs.getInfo()

# %%
myDict['features']
# Out:
# [{'type': 'Image',
#   'bands': [{'id': 'B1',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B2',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B3',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B4',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B5',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B6',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B7',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B9',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B10',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B11',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'QA_PIXEL',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'probability',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]}],
#   'id': '2021-08-17',
#   'properties': {'RADIANCE_MULT_BAND_2': 0.012543,
#    'WRS_TYPE': 2,
#    'K2_CONSTANT_BAND_11': 1201.1442,
#    'valids': 0.020609877353772506,
#    'K2_CONSTANT_BAND_10': 1321.0789,
#    'REFLECTIVE_SAMPLES': 7771,
#    'SUN_AZIMUTH': 40.599406,
#    'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#    'DATE_ACQUIRED': '2021-08-16',
#    'ELLIPSOID': 'WGS84',
#    'STATION_ID': 'LGN',
#    'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#    'ORIENTATION': 'NORTH_UP',
#    'WRS_ROW': 81,
#    'RADIANCE_MULT_BAND_9': 0.0023309,
#    'TARGET_WRS_ROW': 81,
#    'RADIANCE_MULT_BAND_7': 0.00049993,
#    'RADIANCE_MULT_BAND_8': 0.01103,
#    'IMAGE_QUALITY_TIRS': 9,
#    'TRUNCATION_OLI': 'UPPER',
#    'CLOUD_COVER': 3.48,
#    'GEOMETRIC_RMSE_VERIFY': 4.22,
#    'COLLECTION_CATEGORY': 'T1',
#    'GRID_CELL_SIZE_REFLECTIVE': 30,
#    'CLOUD_COVER_LAND': 0.03,
#    'GEOMETRIC_RMSE_MODEL': 7.523,
#    'COLLECTION_NUMBER': 2,
#    'IMAGE_QUALITY_OLI': 9,
#    'LANDSAT_SCENE_ID': 'LC80880812021228LGN00',
#    'WRS_PATH': 88,
#    'PANCHROMATIC_SAMPLES': 15541,
#    'PANCHROMATIC_LINES': 15681,
#    'GEOMETRIC_RMSE_MODEL_Y': 5.721,
#    'REFLECTIVE_LINES': 7841,
#    'GEOMETRIC_RMSE_MODEL_X': 4.885,
#    'system:index': '2021-08-17',
#    'DATA_SOURCE_ELEVATION': 'GLS2000',
#    'REFLECTANCE_ADD_BAND_1': -0.1,
#    'REFLECTANCE_ADD_BAND_2': -0.1,
#    'DATUM': 'WGS84',
#    'REFLECTANCE_ADD_BAND_3': -0.1,
#    'REFLECTANCE_ADD_BAND_4': -0.1,
#    'REFLECTANCE_ADD_BAND_5': -0.1,
#    'REFLECTANCE_ADD_BAND_6': -0.1,
#    'REFLECTANCE_ADD_BAND_7': -0.1,
#    'REFLECTANCE_ADD_BAND_8': -0.1,
#    'GROUND_CONTROL_POINTS_VERSION': 5,
#    'UTM_ZONE': 56,
#    'LANDSAT_PRODUCT_ID': 'LC08_L1TP_088081_20210816_20210827_02_T1',
#    'REFLECTANCE_ADD_BAND_9': -0.1,
#    'GRID_CELL_SIZE_PANCHROMATIC': 15,
#    'RADIANCE_ADD_BAND_4': -48.7311,
#    'REFLECTANCE_MULT_BAND_7': 2e-05,
#    'system:time_start': 1629157025766.5,
#    'RADIANCE_ADD_BAND_5': -29.82101,
#    'REFLECTANCE_MULT_BAND_6': 2e-05,
#    'RADIANCE_ADD_BAND_6': -7.41621,
#    'REFLECTANCE_MULT_BAND_9': 2e-05,
#    'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.5.0',
#    'RADIANCE_ADD_BAND_7': -2.49966,
#    'REFLECTANCE_MULT_BAND_8': 2e-05,
#    'RADIANCE_ADD_BAND_1': -61.24212,
#    'RADIANCE_ADD_BAND_2': -62.71268,
#    'RADIANCE_ADD_BAND_3': -57.78919,
#    'REFLECTANCE_MULT_BAND_1': 2e-05,
#    'RADIANCE_ADD_BAND_8': -55.1502,
#    'REFLECTANCE_MULT_BAND_3': 2e-05,
#    'RADIANCE_ADD_BAND_9': -11.65473,
#    'REFLECTANCE_MULT_BAND_2': 2e-05,
#    'REFLECTANCE_MULT_BAND_5': 2e-05,
#    'REFLECTANCE_MULT_BAND_4': 2e-05,
#    'THERMAL_LINES': 7841,
#    'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#    'GRID_CELL_SIZE_THERMAL': 30,
#    'cloud_probability': 0.005335240046049334,
#    'NADIR_OFFNADIR': 'NADIR',
#    'RADIANCE_ADD_BAND_11': 0.1,
#    'REQUEST_ID': 'P700ypo3mnl8r_00007',
#    'EARTH_SUN_DISTANCE': 1.012468,
#    'TIRS_SSM_MODEL': 'FINAL',
#    'SCENE_CENTER_TIME': '23:36:53.7917670Z',
#    'SUN_ELEVATION': 36.11742839,
#    'RADIANCE_ADD_BAND_10': 0.1,
#    'ROLL_ANGLE': -0.001,
#    'DATE_PRODUCT_GENERATED': 1630024884000,
#    'K1_CONSTANT_BAND_10': 774.8853,
#    'SATURATION_BAND_1': 'N',
#    'SATURATION_BAND_2': 'N',
#    'SATURATION_BAND_3': 'N',
#    'SATURATION_BAND_4': 'N',
#    'SATURATION_BAND_5': 'N',
#    'MAP_PROJECTION': 'UTM',
#    'SATURATION_BAND_6': 'N',
#    'SENSOR_ID': 'OLI_TIRS',
#    'SATURATION_BAND_7': 'Y',
#    'K1_CONSTANT_BAND_11': 480.8883,
#    'SATURATION_BAND_8': 'N',
#    'SATURATION_BAND_9': 'N',
#    'TARGET_WRS_PATH': 88,
#    'PROCESSING_LEVEL': 'L1TP',
#    'RADIANCE_MULT_BAND_11': 0.0003342,
#    'RADIANCE_MULT_BAND_10': 0.0003342,
#    'GROUND_CONTROL_POINTS_MODEL': 51,
#    'SPACECRAFT_ID': 'LANDSAT_8',
#    'THERMAL_SAMPLES': 7771,
#    'GROUND_CONTROL_POINTS_VERIFY': 21,
#    'RADIANCE_MULT_BAND_5': 0.0059642,
#    'RADIANCE_MULT_BAND_6': 0.0014832,
#    'RADIANCE_MULT_BAND_3': 0.011558,
#    'RADIANCE_MULT_BAND_4': 0.0097462,
#    'RADIANCE_MULT_BAND_1': 0.012248}},
#  {'type': 'Image',
#   'bands': [{'id': 'B1',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B2',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B3',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B4',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B5',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B6',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B7',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B9',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B10',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B11',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'QA_PIXEL',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'probability',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]}],
#   'id': '2021-09-02',
#   'properties': {'RADIANCE_MULT_BAND_2': 0.012628,
#    'WRS_TYPE': 2,
#    'K2_CONSTANT_BAND_11': 1201.1442,
#    'valids': 0.020656210907461,
#    'K2_CONSTANT_BAND_10': 1321.0789,
#    'REFLECTIVE_SAMPLES': 7771,
#    'SUN_AZIMUTH': 43.61805046,
#    'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#    'DATE_ACQUIRED': '2021-09-01',
#    'ELLIPSOID': 'WGS84',
#    'STATION_ID': 'LGN',
#    'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#    'ORIENTATION': 'NORTH_UP',
#    'WRS_ROW': 81,
#    'RADIANCE_MULT_BAND_9': 0.0023468,
#    'TARGET_WRS_ROW': 81,
#    'RADIANCE_MULT_BAND_7': 0.00050332,
#    'RADIANCE_MULT_BAND_8': 0.011105,
#    'IMAGE_QUALITY_TIRS': 9,
#    'TRUNCATION_OLI': 'UPPER',
#    'CLOUD_COVER': 10.97,
#    'GEOMETRIC_RMSE_VERIFY': 12.473,
#    'COLLECTION_CATEGORY': 'T1',
#    'GRID_CELL_SIZE_REFLECTIVE': 30,
#    'CLOUD_COVER_LAND': 29.54,
#    'GEOMETRIC_RMSE_MODEL': 7.706,
#    'COLLECTION_NUMBER': 2,
#    'IMAGE_QUALITY_OLI': 9,
#    'LANDSAT_SCENE_ID': 'LC80880812021244LGN00',
#    'WRS_PATH': 88,
#    'PANCHROMATIC_SAMPLES': 15541,
#    'PANCHROMATIC_LINES': 15681,
#    'GEOMETRIC_RMSE_MODEL_Y': 6.101,
#    'REFLECTIVE_LINES': 7841,
#    'GEOMETRIC_RMSE_MODEL_X': 4.709,
#    'system:index': '2021-09-02',
#    'DATA_SOURCE_ELEVATION': 'GLS2000',
#    'REFLECTANCE_ADD_BAND_1': -0.1,
#    'REFLECTANCE_ADD_BAND_2': -0.1,
#    'DATUM': 'WGS84',
#    'REFLECTANCE_ADD_BAND_3': -0.1,
#    'REFLECTANCE_ADD_BAND_4': -0.1,
#    'REFLECTANCE_ADD_BAND_5': -0.1,
#    'REFLECTANCE_ADD_BAND_6': -0.1,
#    'REFLECTANCE_ADD_BAND_7': -0.1,
#    'REFLECTANCE_ADD_BAND_8': -0.1,
#    'GROUND_CONTROL_POINTS_VERSION': 5,
#    'UTM_ZONE': 56,
#    'LANDSAT_PRODUCT_ID': 'LC08_L1TP_088081_20210901_20210909_02_T1',
#    'REFLECTANCE_ADD_BAND_9': -0.1,
#    'GRID_CELL_SIZE_PANCHROMATIC': 15,
#    'RADIANCE_ADD_BAND_4': -49.0618,
#    'REFLECTANCE_MULT_BAND_7': 2e-05,
#    'system:time_start': 1630539430399,
#    'RADIANCE_ADD_BAND_5': -30.02337,
#    'REFLECTANCE_MULT_BAND_6': 2e-05,
#    'RADIANCE_ADD_BAND_6': -7.46654,
#    'REFLECTANCE_MULT_BAND_9': 2e-05,
#    'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.5.0',
#    'RADIANCE_ADD_BAND_7': -2.51662,
#    'REFLECTANCE_MULT_BAND_8': 2e-05,
#    'RADIANCE_ADD_BAND_1': -61.65771,
#    'RADIANCE_ADD_BAND_2': -63.13825,
#    'RADIANCE_ADD_BAND_3': -58.18136,
#    'REFLECTANCE_MULT_BAND_1': 2e-05,
#    'RADIANCE_ADD_BAND_8': -55.52445,
#    'REFLECTANCE_MULT_BAND_3': 2e-05,
#    'RADIANCE_ADD_BAND_9': -11.73382,
#    'REFLECTANCE_MULT_BAND_2': 2e-05,
#    'REFLECTANCE_MULT_BAND_5': 2e-05,
#    'REFLECTANCE_MULT_BAND_4': 2e-05,
#    'THERMAL_LINES': 7841,
#    'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#    'GRID_CELL_SIZE_THERMAL': 30,
#    'cloud_probability': 8.3526797762647,
#    'NADIR_OFFNADIR': 'NADIR',
#    'RADIANCE_ADD_BAND_11': 0.1,
#    'REQUEST_ID': 'P7010irys2e1y_00007',
#    'EARTH_SUN_DISTANCE': 1.0090501,
#    'TIRS_SSM_MODEL': 'FINAL',
#    'SCENE_CENTER_TIME': '23:36:58.4242719Z',
#    'SUN_ELEVATION': 41.20738085,
#    'RADIANCE_ADD_BAND_10': 0.1,
#    'ROLL_ANGLE': -0.001,
#    'DATE_PRODUCT_GENERATED': 1631228256000,
#    'K1_CONSTANT_BAND_10': 774.8853,
#    'SATURATION_BAND_1': 'N',
#    'SATURATION_BAND_2': 'N',
#    'SATURATION_BAND_3': 'N',
#    'SATURATION_BAND_4': 'N',
#    'SATURATION_BAND_5': 'N',
#    'MAP_PROJECTION': 'UTM',
#    'SATURATION_BAND_6': 'N',
#    'SENSOR_ID': 'OLI_TIRS',
#    'SATURATION_BAND_7': 'N',
#    'K1_CONSTANT_BAND_11': 480.8883,
#    'SATURATION_BAND_8': 'N',
#    'SATURATION_BAND_9': 'N',
#    'TARGET_WRS_PATH': 88,
#    'PROCESSING_LEVEL': 'L1TP',
#    'RADIANCE_MULT_BAND_11': 0.0003342,
#    'RADIANCE_MULT_BAND_10': 0.0003342,
#    'GROUND_CONTROL_POINTS_MODEL': 30,
#    'SPACECRAFT_ID': 'LANDSAT_8',
#    'THERMAL_SAMPLES': 7771,
#    'GROUND_CONTROL_POINTS_VERIFY': 21,
#    'RADIANCE_MULT_BAND_5': 0.0060047,
#    'RADIANCE_MULT_BAND_6': 0.0014933,
#    'RADIANCE_MULT_BAND_3': 0.011636,
#    'RADIANCE_MULT_BAND_4': 0.0098124,
#    'RADIANCE_MULT_BAND_1': 0.012332}},
#  {'type': 'Image',
#   'bands': [{'id': 'B1',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B2',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B3',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B4',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B5',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B6',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B7',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B9',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B10',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B11',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'QA_PIXEL',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'probability',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]}],
#   'id': '2021-08-08',
#   'properties': {'RADIANCE_MULT_BAND_2': 0.012503,
#    'WRS_TYPE': 2,
#    'K2_CONSTANT_BAND_11': 1201.1442,
#    'valids': 0.44834741648156184,
#    'K2_CONSTANT_BAND_10': 1321.0789,
#    'REFLECTIVE_SAMPLES': 7711,
#    'SUN_AZIMUTH': 39.09067378,
#    'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#    'DATE_ACQUIRED': '2021-08-07',
#    'ELLIPSOID': 'WGS84',
#    'STATION_ID': 'LGN',
#    'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#    'ORIENTATION': 'NORTH_UP',
#    'WRS_ROW': 81,
#    'RADIANCE_MULT_BAND_9': 0.0023237,
#    'TARGET_WRS_ROW': 81,
#    'RADIANCE_MULT_BAND_7': 0.00049837,
#    'RADIANCE_MULT_BAND_8': 0.010996,
#    'IMAGE_QUALITY_TIRS': 9,
#    'TRUNCATION_OLI': 'UPPER',
#    'CLOUD_COVER': 40.43,
#    'GEOMETRIC_RMSE_VERIFY': 2.64,
#    'COLLECTION_CATEGORY': 'T1',
#    'GRID_CELL_SIZE_REFLECTIVE': 30,
#    'CLOUD_COVER_LAND': 43.57,
#    'GEOMETRIC_RMSE_MODEL': 5.415,
#    'COLLECTION_NUMBER': 2,
#    'IMAGE_QUALITY_OLI': 9,
#    'LANDSAT_SCENE_ID': 'LC80890812021219LGN00',
#    'WRS_PATH': 89,
#    'PANCHROMATIC_SAMPLES': 15421,
#    'PANCHROMATIC_LINES': 15561,
#    'GEOMETRIC_RMSE_MODEL_Y': 3.945,
#    'REFLECTIVE_LINES': 7781,
#    'GEOMETRIC_RMSE_MODEL_X': 3.71,
#    'system:index': '2021-08-08',
#    'DATA_SOURCE_ELEVATION': 'GLS2000',
#    'REFLECTANCE_ADD_BAND_1': -0.1,
#    'REFLECTANCE_ADD_BAND_2': -0.1,
#    'DATUM': 'WGS84',
#    'REFLECTANCE_ADD_BAND_3': -0.1,
#    'REFLECTANCE_ADD_BAND_4': -0.1,
#    'REFLECTANCE_ADD_BAND_5': -0.1,
#    'REFLECTANCE_ADD_BAND_6': -0.1,
#    'REFLECTANCE_ADD_BAND_7': -0.1,
#    'REFLECTANCE_ADD_BAND_8': -0.1,
#    'GROUND_CONTROL_POINTS_VERSION': 5,
#    'UTM_ZONE': 56,
#    'LANDSAT_PRODUCT_ID': 'LC08_L1TP_089081_20210807_20210818_02_T1',
#    'REFLECTANCE_ADD_BAND_9': -0.1,
#    'GRID_CELL_SIZE_PANCHROMATIC': 15,
#    'RADIANCE_ADD_BAND_4': -48.57897,
#    'REFLECTANCE_MULT_BAND_7': 2e-05,
#    'system:time_start': 1628379829493,
#    'RADIANCE_ADD_BAND_5': -29.7279,
#    'REFLECTANCE_MULT_BAND_6': 2e-05,
#    'RADIANCE_ADD_BAND_6': -7.39306,
#    'REFLECTANCE_MULT_BAND_9': 2e-05,
#    'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.5.0',
#    'RADIANCE_ADD_BAND_7': -2.49186,
#    'REFLECTANCE_MULT_BAND_8': 2e-05,
#    'RADIANCE_ADD_BAND_1': -61.05092,
#    'RADIANCE_ADD_BAND_2': -62.51689,
#    'RADIANCE_ADD_BAND_3': -57.60878,
#    'REFLECTANCE_MULT_BAND_1': 2e-05,
#    'RADIANCE_ADD_BAND_8': -54.97802,
#    'REFLECTANCE_MULT_BAND_3': 2e-05,
#    'RADIANCE_ADD_BAND_9': -11.61834,
#    'REFLECTANCE_MULT_BAND_2': 2e-05,
#    'REFLECTANCE_MULT_BAND_5': 2e-05,
#    'REFLECTANCE_MULT_BAND_4': 2e-05,
#    'THERMAL_LINES': 7781,
#    'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#    'GRID_CELL_SIZE_THERMAL': 30,
#    'cloud_probability': 68.51674044813262,
#    'NADIR_OFFNADIR': 'NADIR',
#    'RADIANCE_ADD_BAND_11': 0.1,
#    'REQUEST_ID': 'P700y9v1gfmg6_00010',
#    'EARTH_SUN_DISTANCE': 1.0140522,
#    'TIRS_SSM_MODEL': 'FINAL',
#    'SCENE_CENTER_TIME': '23:43:01.5840670Z',
#    'SUN_ELEVATION': 33.66558815,
#    'RADIANCE_ADD_BAND_10': 0.1,
#    'ROLL_ANGLE': 0,
#    'DATE_PRODUCT_GENERATED': 1629328362000,
#    'K1_CONSTANT_BAND_10': 774.8853,
#    'SATURATION_BAND_1': 'N',
#    'SATURATION_BAND_2': 'N',
#    'SATURATION_BAND_3': 'N',
#    'SATURATION_BAND_4': 'N',
#    'SATURATION_BAND_5': 'N',
#    'MAP_PROJECTION': 'UTM',
#    'SATURATION_BAND_6': 'N',
#    'SENSOR_ID': 'OLI_TIRS',
#    'SATURATION_BAND_7': 'Y',
#    'K1_CONSTANT_BAND_11': 480.8883,
#    'SATURATION_BAND_8': 'N',
#    'SATURATION_BAND_9': 'N',
#    'TARGET_WRS_PATH': 89,
#    'PROCESSING_LEVEL': 'L1TP',
#    'RADIANCE_MULT_BAND_11': 0.0003342,
#    'RADIANCE_MULT_BAND_10': 0.0003342,
#    'GROUND_CONTROL_POINTS_MODEL': 338,
#    'SPACECRAFT_ID': 'LANDSAT_8',
#    'THERMAL_SAMPLES': 7711,
#    'GROUND_CONTROL_POINTS_VERIFY': 88,
#    'RADIANCE_MULT_BAND_5': 0.0059456,
#    'RADIANCE_MULT_BAND_6': 0.0014786,
#    'RADIANCE_MULT_BAND_3': 0.011522,
#    'RADIANCE_MULT_BAND_4': 0.0097158,
#    'RADIANCE_MULT_BAND_1': 0.01221}},
#  {'type': 'Image',
#   'bands': [{'id': 'B1',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B2',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B3',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B4',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B5',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B6',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B7',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B9',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B10',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B11',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'QA_PIXEL',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'probability',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]}],
#   'id': '2021-08-24',
#   'properties': {'RADIANCE_MULT_BAND_2': 0.012578,
#    'WRS_TYPE': 2,
#    'K2_CONSTANT_BAND_11': 1201.1442,
#    'valids': 0.19723312136799537,
#    'K2_CONSTANT_BAND_10': 1321.0789,
#    'REFLECTIVE_SAMPLES': 7711,
#    'SUN_AZIMUTH': 41.85925216,
#    'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#    'DATE_ACQUIRED': '2021-08-23',
#    'ELLIPSOID': 'WGS84',
#    'STATION_ID': 'LGN',
#    'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#    'ORIENTATION': 'NORTH_UP',
#    'WRS_ROW': 81,
#    'RADIANCE_MULT_BAND_9': 0.0023375,
#    'TARGET_WRS_ROW': 81,
#    'RADIANCE_MULT_BAND_7': 0.00050134,
#    'RADIANCE_MULT_BAND_8': 0.011061,
#    'IMAGE_QUALITY_TIRS': 9,
#    'TRUNCATION_OLI': 'UPPER',
#    'CLOUD_COVER': 76.51,
#    'COLLECTION_CATEGORY': 'T1',
#    'GRID_CELL_SIZE_REFLECTIVE': 30,
#    'CLOUD_COVER_LAND': 70.98,
#    'GEOMETRIC_RMSE_MODEL': 7.099,
#    'COLLECTION_NUMBER': 2,
#    'IMAGE_QUALITY_OLI': 9,
#    'LANDSAT_SCENE_ID': 'LC80890812021235LGN00',
#    'WRS_PATH': 89,
#    'PANCHROMATIC_SAMPLES': 15421,
#    'PANCHROMATIC_LINES': 15561,
#    'GEOMETRIC_RMSE_MODEL_Y': 5.26,
#    'REFLECTIVE_LINES': 7781,
#    'GEOMETRIC_RMSE_MODEL_X': 4.767,
#    'system:index': '2021-08-24',
#    'DATA_SOURCE_ELEVATION': 'GLS2000',
#    'REFLECTANCE_ADD_BAND_1': -0.1,
#    'REFLECTANCE_ADD_BAND_2': -0.1,
#    'DATUM': 'WGS84',
#    'REFLECTANCE_ADD_BAND_3': -0.1,
#    'REFLECTANCE_ADD_BAND_4': -0.1,
#    'REFLECTANCE_ADD_BAND_5': -0.1,
#    'REFLECTANCE_ADD_BAND_6': -0.1,
#    'REFLECTANCE_ADD_BAND_7': -0.1,
#    'REFLECTANCE_ADD_BAND_8': -0.1,
#    'GROUND_CONTROL_POINTS_VERSION': 5,
#    'UTM_ZONE': 56,
#    'LANDSAT_PRODUCT_ID': 'LC08_L1TP_089081_20210823_20210901_02_T1',
#    'REFLECTANCE_ADD_BAND_9': -0.1,
#    'GRID_CELL_SIZE_PANCHROMATIC': 15,
#    'RADIANCE_ADD_BAND_4': -48.86877,
#    'REFLECTANCE_MULT_BAND_7': 2e-05,
#    'system:time_start': 1629762198397.5,
#    'RADIANCE_ADD_BAND_5': -29.90525,
#    'REFLECTANCE_MULT_BAND_6': 2e-05,
#    'RADIANCE_ADD_BAND_6': -7.43716,
#    'REFLECTANCE_MULT_BAND_9': 2e-05,
#    'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.5.0',
#    'RADIANCE_ADD_BAND_7': -2.50672,
#    'REFLECTANCE_MULT_BAND_8': 2e-05,
#    'RADIANCE_ADD_BAND_1': -61.41513,
#    'RADIANCE_ADD_BAND_2': -62.88984,
#    'RADIANCE_ADD_BAND_3': -57.95245,
#    'REFLECTANCE_MULT_BAND_1': 2e-05,
#    'RADIANCE_ADD_BAND_8': -55.306,
#    'REFLECTANCE_MULT_BAND_3': 2e-05,
#    'RADIANCE_ADD_BAND_9': -11.68765,
#    'REFLECTANCE_MULT_BAND_2': 2e-05,
#    'REFLECTANCE_MULT_BAND_5': 2e-05,
#    'REFLECTANCE_MULT_BAND_4': 2e-05,
#    'THERMAL_LINES': 7781,
#    'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#    'GRID_CELL_SIZE_THERMAL': 30,
#    'cloud_probability': 90.261769306842,
#    'NADIR_OFFNADIR': 'NADIR',
#    'RADIANCE_ADD_BAND_11': 0.1,
#    'REQUEST_ID': 'P701017ujyxba_00010',
#    'EARTH_SUN_DISTANCE': 1.0110409,
#    'TIRS_SSM_MODEL': 'FINAL',
#    'SCENE_CENTER_TIME': '23:43:06.4226890Z',
#    'SUN_ELEVATION': 38.24935412,
#    'RADIANCE_ADD_BAND_10': 0.1,
#    'ROLL_ANGLE': -0.001,
#    'DATE_PRODUCT_GENERATED': 1630461596000,
#    'K1_CONSTANT_BAND_10': 774.8853,
#    'SATURATION_BAND_1': 'N',
#    'SATURATION_BAND_2': 'N',
#    'SATURATION_BAND_3': 'N',
#    'SATURATION_BAND_4': 'N',
#    'SATURATION_BAND_5': 'N',
#    'MAP_PROJECTION': 'UTM',
#    'SATURATION_BAND_6': 'N',
#    'SENSOR_ID': 'OLI_TIRS',
#    'SATURATION_BAND_7': 'N',
#    'K1_CONSTANT_BAND_11': 480.8883,
#    'SATURATION_BAND_8': 'N',
#    'SATURATION_BAND_9': 'N',
#    'TARGET_WRS_PATH': 89,
#    'PROCESSING_LEVEL': 'L1TP',
#    'RADIANCE_MULT_BAND_11': 0.0003342,
#    'RADIANCE_MULT_BAND_10': 0.0003342,
#    'GROUND_CONTROL_POINTS_MODEL': 73,
#    'SPACECRAFT_ID': 'LANDSAT_8',
#    'THERMAL_SAMPLES': 7711,
#    'RADIANCE_MULT_BAND_5': 0.0059811,
#    'RADIANCE_MULT_BAND_6': 0.0014874,
#    'RADIANCE_MULT_BAND_3': 0.01159,
#    'RADIANCE_MULT_BAND_4': 0.0097738,
#    'RADIANCE_MULT_BAND_1': 0.012283}},
#  {'type': 'Image',
#   'bands': [{'id': 'B1',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B2',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B3',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B4',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B5',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B6',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B7',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B9',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B10',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B11',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'QA_PIXEL',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'probability',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]}],
#   'id': '2021-08-15',
#   'properties': {'RADIANCE_MULT_BAND_2': 0.012533,
#    'WRS_TYPE': 2,
#    'K2_CONSTANT_BAND_11': 1201.1442,
#    'valids': 0.5250082793272145,
#    'K2_CONSTANT_BAND_10': 1321.0789,
#    'REFLECTIVE_SAMPLES': 7641,
#    'SUN_AZIMUTH': 39.88354463,
#    'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#    'DATE_ACQUIRED': '2021-08-14',
#    'ELLIPSOID': 'WGS84',
#    'STATION_ID': 'LGN',
#    'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#    'ORIENTATION': 'NORTH_UP',
#    'WRS_ROW': 82,
#    'RADIANCE_MULT_BAND_9': 0.0023292,
#    'TARGET_WRS_ROW': 82,
#    'RADIANCE_MULT_BAND_7': 0.00049956,
#    'RADIANCE_MULT_BAND_8': 0.011022,
#    'IMAGE_QUALITY_TIRS': 9,
#    'TRUNCATION_OLI': 'UPPER',
#    'CLOUD_COVER': 0.32,
#    'GEOMETRIC_RMSE_VERIFY': 1.752,
#    'COLLECTION_CATEGORY': 'T1',
#    'GRID_CELL_SIZE_REFLECTIVE': 30,
#    'CLOUD_COVER_LAND': 0.32,
#    'GEOMETRIC_RMSE_MODEL': 4.187,
#    'COLLECTION_NUMBER': 2,
#    'IMAGE_QUALITY_OLI': 9,
#    'LANDSAT_SCENE_ID': 'LC80900822021226LGN00',
#    'WRS_PATH': 90,
#    'PANCHROMATIC_SAMPLES': 15281,
#    'PANCHROMATIC_LINES': 15401,
#    'GEOMETRIC_RMSE_MODEL_Y': 3.151,
#    'REFLECTIVE_LINES': 7701,
#    'GEOMETRIC_RMSE_MODEL_X': 2.757,
#    'system:index': '2021-08-15',
#    'DATA_SOURCE_ELEVATION': 'GLS2000',
#    'REFLECTANCE_ADD_BAND_1': -0.1,
#    'REFLECTANCE_ADD_BAND_2': -0.1,
#    'DATUM': 'WGS84',
#    'REFLECTANCE_ADD_BAND_3': -0.1,
#    'REFLECTANCE_ADD_BAND_4': -0.1,
#    'REFLECTANCE_ADD_BAND_5': -0.1,
#    'REFLECTANCE_ADD_BAND_6': -0.1,
#    'REFLECTANCE_ADD_BAND_7': -0.1,
#    'REFLECTANCE_ADD_BAND_8': -0.1,
#    'GROUND_CONTROL_POINTS_VERSION': 5,
#    'UTM_ZONE': 56,
#    'LANDSAT_PRODUCT_ID': 'LC08_L1TP_090082_20210814_20210826_02_T1',
#    'REFLECTANCE_ADD_BAND_9': -0.1,
#    'GRID_CELL_SIZE_PANCHROMATIC': 15,
#    'RADIANCE_ADD_BAND_4': -48.69437,
#    'REFLECTANCE_MULT_BAND_7': 2e-05,
#    'system:time_start': 1628985014687,
#    'RADIANCE_ADD_BAND_5': -29.79853,
#    'REFLECTANCE_MULT_BAND_6': 2e-05,
#    'RADIANCE_ADD_BAND_6': -7.41062,
#    'REFLECTANCE_MULT_BAND_9': 2e-05,
#    'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.5.0',
#    'RADIANCE_ADD_BAND_7': -2.49778,
#    'REFLECTANCE_MULT_BAND_8': 2e-05,
#    'RADIANCE_ADD_BAND_1': -61.19596,
#    'RADIANCE_ADD_BAND_2': -62.66541,
#    'RADIANCE_ADD_BAND_3': -57.74564,
#    'REFLECTANCE_MULT_BAND_1': 2e-05,
#    'RADIANCE_ADD_BAND_8': -55.10863,
#    'REFLECTANCE_MULT_BAND_3': 2e-05,
#    'RADIANCE_ADD_BAND_9': -11.64594,
#    'REFLECTANCE_MULT_BAND_2': 2e-05,
#    'REFLECTANCE_MULT_BAND_5': 2e-05,
#    'REFLECTANCE_MULT_BAND_4': 2e-05,
#    'THERMAL_LINES': 7701,
#    'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#    'GRID_CELL_SIZE_THERMAL': 30,
#    'cloud_probability': 1.5941521114874209,
#    'NADIR_OFFNADIR': 'NADIR',
#    'RADIANCE_ADD_BAND_11': 0.1,
#    'REQUEST_ID': 'P700ypo2vyhnw_00009',
#    'EARTH_SUN_DISTANCE': 1.0128498,
#    'TIRS_SSM_MODEL': 'FINAL',
#    'SCENE_CENTER_TIME': '23:49:38.7535720Z',
#    'SUN_ELEVATION': 34.29089274,
#    'RADIANCE_ADD_BAND_10': 0.1,
#    'ROLL_ANGLE': -0.001,
#    'DATE_PRODUCT_GENERATED': 1630004365000,
#    'K1_CONSTANT_BAND_10': 774.8853,
#    'SATURATION_BAND_1': 'N',
#    'SATURATION_BAND_2': 'N',
#    'SATURATION_BAND_3': 'N',
#    'SATURATION_BAND_4': 'N',
#    'SATURATION_BAND_5': 'N',
#    'MAP_PROJECTION': 'UTM',
#    'SATURATION_BAND_6': 'N',
#    'SENSOR_ID': 'OLI_TIRS',
#    'SATURATION_BAND_7': 'Y',
#    'K1_CONSTANT_BAND_11': 480.8883,
#    'SATURATION_BAND_8': 'N',
#    'SATURATION_BAND_9': 'N',
#    'TARGET_WRS_PATH': 90,
#    'PROCESSING_LEVEL': 'L1TP',
#    'RADIANCE_MULT_BAND_11': 0.0003342,
#    'RADIANCE_MULT_BAND_10': 0.0003342,
#    'GROUND_CONTROL_POINTS_MODEL': 936,
#    'SPACECRAFT_ID': 'LANDSAT_8',
#    'THERMAL_SAMPLES': 7641,
#    'GROUND_CONTROL_POINTS_VERIFY': 213,
#    'RADIANCE_MULT_BAND_5': 0.0059597,
#    'RADIANCE_MULT_BAND_6': 0.0014821,
#    'RADIANCE_MULT_BAND_3': 0.011549,
#    'RADIANCE_MULT_BAND_4': 0.0097389,
#    'RADIANCE_MULT_BAND_1': 0.012239}},
#  {'type': 'Image',
#   'bands': [{'id': 'B1',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B2',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B3',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B4',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B5',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B6',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B7',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B9',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B10',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B11',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'QA_PIXEL',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'probability',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]}],
#   'id': '2021-08-31',
#   'properties': {'RADIANCE_MULT_BAND_2': 0.012616,
#    'WRS_TYPE': 2,
#    'K2_CONSTANT_BAND_11': 1201.1442,
#    'valids': 0.5250843464035878,
#    'K2_CONSTANT_BAND_10': 1321.0789,
#    'REFLECTIVE_SAMPLES': 7631,
#    'SUN_AZIMUTH': 42.6867266,
#    'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#    'DATE_ACQUIRED': '2021-08-30',
#    'ELLIPSOID': 'WGS84',
#    'STATION_ID': 'LGN',
#    'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#    'ORIENTATION': 'NORTH_UP',
#    'WRS_ROW': 82,
#    'RADIANCE_MULT_BAND_9': 0.0023446,
#    'TARGET_WRS_ROW': 82,
#    'RADIANCE_MULT_BAND_7': 0.00050287,
#    'RADIANCE_MULT_BAND_8': 0.011095,
#    'IMAGE_QUALITY_TIRS': 9,
#    'TRUNCATION_OLI': 'UPPER',
#    'CLOUD_COVER': 0.05,
#    'GEOMETRIC_RMSE_VERIFY': 2.153,
#    'COLLECTION_CATEGORY': 'T1',
#    'GRID_CELL_SIZE_REFLECTIVE': 30,
#    'CLOUD_COVER_LAND': 0.05,
#    'GEOMETRIC_RMSE_MODEL': 4.642,
#    'COLLECTION_NUMBER': 2,
#    'IMAGE_QUALITY_OLI': 9,
#    'LANDSAT_SCENE_ID': 'LC80900822021242LGN00',
#    'WRS_PATH': 90,
#    'PANCHROMATIC_SAMPLES': 15261,
#    'PANCHROMATIC_LINES': 15401,
#    'GEOMETRIC_RMSE_MODEL_Y': 3.508,
#    'REFLECTIVE_LINES': 7701,
#    'GEOMETRIC_RMSE_MODEL_X': 3.04,
#    'system:index': '2021-08-31',
#    'DATA_SOURCE_ELEVATION': 'GLS2000',
#    'REFLECTANCE_ADD_BAND_1': -0.1,
#    'REFLECTANCE_ADD_BAND_2': -0.1,
#    'DATUM': 'WGS84',
#    'REFLECTANCE_ADD_BAND_3': -0.1,
#    'REFLECTANCE_ADD_BAND_4': -0.1,
#    'REFLECTANCE_ADD_BAND_5': -0.1,
#    'REFLECTANCE_ADD_BAND_6': -0.1,
#    'REFLECTANCE_ADD_BAND_7': -0.1,
#    'REFLECTANCE_ADD_BAND_8': -0.1,
#    'GROUND_CONTROL_POINTS_VERSION': 5,
#    'UTM_ZONE': 56,
#    'LANDSAT_PRODUCT_ID': 'LC08_L1TP_090082_20210830_20210909_02_T1',
#    'REFLECTANCE_ADD_BAND_9': -0.1,
#    'GRID_CELL_SIZE_PANCHROMATIC': 15,
#    'RADIANCE_ADD_BAND_4': -49.01716,
#    'REFLECTANCE_MULT_BAND_7': 2e-05,
#    'system:time_start': 1630367419251.5,
#    'RADIANCE_ADD_BAND_5': -29.99605,
#    'REFLECTANCE_MULT_BAND_6': 2e-05,
#    'RADIANCE_ADD_BAND_6': -7.45975,
#    'REFLECTANCE_MULT_BAND_9': 2e-05,
#    'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.5.0',
#    'RADIANCE_ADD_BAND_7': -2.51433,
#    'REFLECTANCE_MULT_BAND_8': 2e-05,
#    'RADIANCE_ADD_BAND_1': -61.60161,
#    'RADIANCE_ADD_BAND_2': -63.0808,
#    'RADIANCE_ADD_BAND_3': -58.12842,
#    'REFLECTANCE_MULT_BAND_1': 2e-05,
#    'RADIANCE_ADD_BAND_8': -55.47393,
#    'REFLECTANCE_MULT_BAND_3': 2e-05,
#    'RADIANCE_ADD_BAND_9': -11.72314,
#    'REFLECTANCE_MULT_BAND_2': 2e-05,
#    'REFLECTANCE_MULT_BAND_5': 2e-05,
#    'REFLECTANCE_MULT_BAND_4': 2e-05,
#    'THERMAL_LINES': 7701,
#    'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#    'GRID_CELL_SIZE_THERMAL': 30,
#    'cloud_probability': 0.048489972651372906,
#    'NADIR_OFFNADIR': 'NADIR',
#    'RADIANCE_ADD_BAND_11': 0.1,
#    'REQUEST_ID': 'P7010iry00yr4_00009',
#    'EARTH_SUN_DISTANCE': 1.0095095,
#    'TIRS_SSM_MODEL': 'FINAL',
#    'SCENE_CENTER_TIME': '23:49:43.3222680Z',
#    'SUN_ELEVATION': 39.31982828,
#    'RADIANCE_ADD_BAND_10': 0.1,
#    'ROLL_ANGLE': -0.001,
#    'DATE_PRODUCT_GENERATED': 1631207101000,
#    'K1_CONSTANT_BAND_10': 774.8853,
#    'SATURATION_BAND_1': 'N',
#    'SATURATION_BAND_2': 'N',
#    'SATURATION_BAND_3': 'N',
#    'SATURATION_BAND_4': 'N',
#    'SATURATION_BAND_5': 'N',
#    'MAP_PROJECTION': 'UTM',
#    'SATURATION_BAND_6': 'Y',
#    'SENSOR_ID': 'OLI_TIRS',
#    'SATURATION_BAND_7': 'Y',
#    'K1_CONSTANT_BAND_11': 480.8883,
#    'SATURATION_BAND_8': 'N',
#    'SATURATION_BAND_9': 'N',
#    'TARGET_WRS_PATH': 90,
#    'PROCESSING_LEVEL': 'L1TP',
#    'RADIANCE_MULT_BAND_11': 0.0003342,
#    'RADIANCE_MULT_BAND_10': 0.0003342,
#    'GROUND_CONTROL_POINTS_MODEL': 920,
#    'SPACECRAFT_ID': 'LANDSAT_8',
#    'THERMAL_SAMPLES': 7631,
#    'GROUND_CONTROL_POINTS_VERIFY': 251,
#    'RADIANCE_MULT_BAND_5': 0.0059992,
#    'RADIANCE_MULT_BAND_6': 0.0014919,
#    'RADIANCE_MULT_BAND_3': 0.011626,
#    'RADIANCE_MULT_BAND_4': 0.0098034,
#    'RADIANCE_MULT_BAND_1': 0.01232}},
#  {'type': 'Image',
#   'bands': [{'id': 'B1',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B2',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B3',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B4',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B5',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B6',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B7',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B9',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B10',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B11',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'QA_PIXEL',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'probability',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]}],
#   'id': '2021-08-06',
#   'properties': {'RADIANCE_MULT_BAND_2': 0.012496,
#    'WRS_TYPE': 2,
#    'K2_CONSTANT_BAND_11': 1201.1442,
#    'valids': 0.13446803486979417,
#    'K2_CONSTANT_BAND_10': 1321.0789,
#    'REFLECTIVE_SAMPLES': 7841,
#    'SUN_AZIMUTH': 38.46665429,
#    'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#    'DATE_ACQUIRED': '2021-08-05',
#    'ELLIPSOID': 'WGS84',
#    'STATION_ID': 'LGN',
#    'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#    'ORIENTATION': 'NORTH_UP',
#    'WRS_ROW': 82,
#    'RADIANCE_MULT_BAND_9': 0.0023223,
#    'TARGET_WRS_ROW': 82,
#    'RADIANCE_MULT_BAND_7': 0.00049808,
#    'RADIANCE_MULT_BAND_8': 0.010989,
#    'IMAGE_QUALITY_TIRS': 9,
#    'TRUNCATION_OLI': 'UPPER',
#    'CLOUD_COVER': 54.69,
#    'GEOMETRIC_RMSE_VERIFY': 4.959,
#    'COLLECTION_CATEGORY': 'T1',
#    'GRID_CELL_SIZE_REFLECTIVE': 30,
#    'CLOUD_COVER_LAND': 54.69,
#    'GEOMETRIC_RMSE_MODEL': 7.781,
#    'COLLECTION_NUMBER': 2,
#    'IMAGE_QUALITY_OLI': 9,
#    'LANDSAT_SCENE_ID': 'LC80910822021217LGN00',
#    'WRS_PATH': 91,
#    'PANCHROMATIC_SAMPLES': 15681,
#    'PANCHROMATIC_LINES': 15781,
#    'GEOMETRIC_RMSE_MODEL_Y': 5.794,
#    'REFLECTIVE_LINES': 7891,
#    'GEOMETRIC_RMSE_MODEL_X': 5.195,
#    'system:index': '2021-08-06',
#    'DATA_SOURCE_ELEVATION': 'GLS2000',
#    'REFLECTANCE_ADD_BAND_1': -0.1,
#    'REFLECTANCE_ADD_BAND_2': -0.1,
#    'DATUM': 'WGS84',
#    'REFLECTANCE_ADD_BAND_3': -0.1,
#    'REFLECTANCE_ADD_BAND_4': -0.1,
#    'REFLECTANCE_ADD_BAND_5': -0.1,
#    'REFLECTANCE_ADD_BAND_6': -0.1,
#    'REFLECTANCE_ADD_BAND_7': -0.1,
#    'REFLECTANCE_ADD_BAND_8': -0.1,
#    'GROUND_CONTROL_POINTS_VERSION': 5,
#    'UTM_ZONE': 55,
#    'LANDSAT_PRODUCT_ID': 'LC08_L1TP_091082_20210805_20210811_02_T1',
#    'REFLECTANCE_ADD_BAND_9': -0.1,
#    'GRID_CELL_SIZE_PANCHROMATIC': 15,
#    'RADIANCE_ADD_BAND_4': -48.55071,
#    'REFLECTANCE_MULT_BAND_7': 2e-05,
#    'system:time_start': 1628207770318,
#    'RADIANCE_ADD_BAND_5': -29.71061,
#    'REFLECTANCE_MULT_BAND_6': 2e-05,
#    'RADIANCE_ADD_BAND_6': -7.38876,
#    'REFLECTANCE_MULT_BAND_9': 2e-05,
#    'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.5.0',
#    'RADIANCE_ADD_BAND_7': -2.49041,
#    'REFLECTANCE_MULT_BAND_8': 2e-05,
#    'RADIANCE_ADD_BAND_1': -61.01541,
#    'RADIANCE_ADD_BAND_2': -62.48052,
#    'RADIANCE_ADD_BAND_3': -57.57527,
#    'REFLECTANCE_MULT_BAND_1': 2e-05,
#    'RADIANCE_ADD_BAND_8': -54.94604,
#    'REFLECTANCE_MULT_BAND_3': 2e-05,
#    'RADIANCE_ADD_BAND_9': -11.61158,
#    'REFLECTANCE_MULT_BAND_2': 2e-05,
#    'REFLECTANCE_MULT_BAND_5': 2e-05,
#    'REFLECTANCE_MULT_BAND_4': 2e-05,
#    'THERMAL_LINES': 7891,
#    'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#    'GRID_CELL_SIZE_THERMAL': 30,
#    'cloud_probability': 66.71947564855657,
#    'NADIR_OFFNADIR': 'NADIR',
#    'RADIANCE_ADD_BAND_11': 0.1,
#    'REQUEST_ID': 'P700xssw97b4k_00011',
#    'EARTH_SUN_DISTANCE': 1.0143473,
#    'TIRS_SSM_MODEL': 'FINAL',
#    'SCENE_CENTER_TIME': '23:55:46.3635210Z',
#    'SUN_ELEVATION': 31.89948585,
#    'RADIANCE_ADD_BAND_10': 0.1,
#    'ROLL_ANGLE': -0.001,
#    'DATE_PRODUCT_GENERATED': 1628679287000,
#    'K1_CONSTANT_BAND_10': 774.8853,
#    'SATURATION_BAND_1': 'N',
#    'SATURATION_BAND_2': 'N',
#    'SATURATION_BAND_3': 'N',
#    'SATURATION_BAND_4': 'N',
#    'SATURATION_BAND_5': 'N',
#    'MAP_PROJECTION': 'UTM',
#    'SATURATION_BAND_6': 'N',
#    'SENSOR_ID': 'OLI_TIRS',
#    'SATURATION_BAND_7': 'Y',
#    'K1_CONSTANT_BAND_11': 480.8883,
#    'SATURATION_BAND_8': 'N',
#    'SATURATION_BAND_9': 'N',
#    'TARGET_WRS_PATH': 91,
#    'PROCESSING_LEVEL': 'L1TP',
#    'RADIANCE_MULT_BAND_11': 0.0003342,
#    'RADIANCE_MULT_BAND_10': 0.0003342,
#    'GROUND_CONTROL_POINTS_MODEL': 202,
#    'SPACECRAFT_ID': 'LANDSAT_8',
#    'THERMAL_SAMPLES': 7841,
#    'GROUND_CONTROL_POINTS_VERIFY': 71,
#    'RADIANCE_MULT_BAND_5': 0.0059421,
#    'RADIANCE_MULT_BAND_6': 0.0014778,
#    'RADIANCE_MULT_BAND_3': 0.011515,
#    'RADIANCE_MULT_BAND_4': 0.0097101,
#    'RADIANCE_MULT_BAND_1': 0.012203}},
#  {'type': 'Image',
#   'bands': [{'id': 'B1',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B2',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B3',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B4',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B5',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B6',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B7',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B9',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B10',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B11',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'QA_PIXEL',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'probability',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]}],
#   'id': '2021-08-22',
#   'properties': {'RADIANCE_MULT_BAND_2': 0.012568,
#    'WRS_TYPE': 2,
#    'K2_CONSTANT_BAND_11': 1201.1442,
#    'valids': 0.13449558882008988,
#    'K2_CONSTANT_BAND_10': 1321.0789,
#    'REFLECTIVE_SAMPLES': 7841,
#    'SUN_AZIMUTH': 41.06123367,
#    'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#    'DATE_ACQUIRED': '2021-08-21',
#    'ELLIPSOID': 'WGS84',
#    'STATION_ID': 'LGN',
#    'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#    'ORIENTATION': 'NORTH_UP',
#    'WRS_ROW': 82,
#    'RADIANCE_MULT_BAND_9': 0.0023356,
#    'TARGET_WRS_ROW': 82,
#    'RADIANCE_MULT_BAND_7': 0.00050093,
#    'RADIANCE_MULT_BAND_8': 0.011052,
#    'IMAGE_QUALITY_TIRS': 9,
#    'TRUNCATION_OLI': 'UPPER',
#    'CLOUD_COVER': 10.8,
#    'GEOMETRIC_RMSE_VERIFY': 4.787,
#    'COLLECTION_CATEGORY': 'T1',
#    'GRID_CELL_SIZE_REFLECTIVE': 30,
#    'CLOUD_COVER_LAND': 10.8,
#    'GEOMETRIC_RMSE_MODEL': 6.956,
#    'COLLECTION_NUMBER': 2,
#    'IMAGE_QUALITY_OLI': 9,
#    'LANDSAT_SCENE_ID': 'LC80910822021233LGN00',
#    'WRS_PATH': 91,
#    'PANCHROMATIC_SAMPLES': 15681,
#    'PANCHROMATIC_LINES': 15781,
#    'GEOMETRIC_RMSE_MODEL_Y': 5.134,
#    'REFLECTIVE_LINES': 7891,
#    'GEOMETRIC_RMSE_MODEL_X': 4.694,
#    'system:index': '2021-08-22',
#    'DATA_SOURCE_ELEVATION': 'GLS2000',
#    'REFLECTANCE_ADD_BAND_1': -0.1,
#    'REFLECTANCE_ADD_BAND_2': -0.1,
#    'DATUM': 'WGS84',
#    'REFLECTANCE_ADD_BAND_3': -0.1,
#    'REFLECTANCE_ADD_BAND_4': -0.1,
#    'REFLECTANCE_ADD_BAND_5': -0.1,
#    'REFLECTANCE_ADD_BAND_6': -0.1,
#    'REFLECTANCE_ADD_BAND_7': -0.1,
#    'REFLECTANCE_ADD_BAND_8': -0.1,
#    'GROUND_CONTROL_POINTS_VERSION': 5,
#    'UTM_ZONE': 55,
#    'LANDSAT_PRODUCT_ID': 'LC08_L1TP_091082_20210821_20210827_02_T1',
#    'REFLECTANCE_ADD_BAND_9': -0.1,
#    'GRID_CELL_SIZE_PANCHROMATIC': 15,
#    'RADIANCE_ADD_BAND_4': -48.82857,
#    'REFLECTANCE_MULT_BAND_7': 2e-05,
#    'system:time_start': 1629590175482,
#    'RADIANCE_ADD_BAND_5': -29.88065,
#    'REFLECTANCE_MULT_BAND_6': 2e-05,
#    'RADIANCE_ADD_BAND_6': -7.43105,
#    'REFLECTANCE_MULT_BAND_9': 2e-05,
#    'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.5.0',
#    'RADIANCE_ADD_BAND_7': -2.50466,
#    'REFLECTANCE_MULT_BAND_8': 2e-05,
#    'RADIANCE_ADD_BAND_1': -61.36461,
#    'RADIANCE_ADD_BAND_2': -62.8381,
#    'RADIANCE_ADD_BAND_3': -57.90478,
#    'REFLECTANCE_MULT_BAND_1': 2e-05,
#    'RADIANCE_ADD_BAND_8': -55.2605,
#    'REFLECTANCE_MULT_BAND_3': 2e-05,
#    'RADIANCE_ADD_BAND_9': -11.67804,
#    'REFLECTANCE_MULT_BAND_2': 2e-05,
#    'REFLECTANCE_MULT_BAND_5': 2e-05,
#    'REFLECTANCE_MULT_BAND_4': 2e-05,
#    'THERMAL_LINES': 7891,
#    'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#    'GRID_CELL_SIZE_THERMAL': 30,
#    'cloud_probability': 9.02761904802159,
#    'NADIR_OFFNADIR': 'NADIR',
#    'RADIANCE_ADD_BAND_11': 0.1,
#    'REQUEST_ID': 'P700ypo7kw8yv_00011',
#    'EARTH_SUN_DISTANCE': 1.0114571,
#    'TIRS_SSM_MODEL': 'FINAL',
#    'SCENE_CENTER_TIME': '23:55:51.5238429Z',
#    'SUN_ELEVATION': 36.3870624,
#    'RADIANCE_ADD_BAND_10': 0.1,
#    'ROLL_ANGLE': -0.001,
#    'DATE_PRODUCT_GENERATED': 1630092780000,
#    'K1_CONSTANT_BAND_10': 774.8853,
#    'SATURATION_BAND_1': 'N',
#    'SATURATION_BAND_2': 'N',
#    'SATURATION_BAND_3': 'N',
#    'SATURATION_BAND_4': 'N',
#    'SATURATION_BAND_5': 'N',
#    'MAP_PROJECTION': 'UTM',
#    'SATURATION_BAND_6': 'Y',
#    'SENSOR_ID': 'OLI_TIRS',
#    'SATURATION_BAND_7': 'Y',
#    'K1_CONSTANT_BAND_11': 480.8883,
#    'SATURATION_BAND_8': 'N',
#    'SATURATION_BAND_9': 'N',
#    'TARGET_WRS_PATH': 91,
#    'PROCESSING_LEVEL': 'L1TP',
#    'RADIANCE_MULT_BAND_11': 0.0003342,
# ...
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]}],
#   'id': '2021-08-29',
#   'properties': {'RADIANCE_MULT_BAND_2': 0.012605,
#    'WRS_TYPE': 2,
#    'K2_CONSTANT_BAND_11': 1201.1442,
#    'valids': 0.20753730229065254,
#    'K2_CONSTANT_BAND_10': 1321.0789,
#    'REFLECTIVE_SAMPLES': 7771,
#    'SUN_AZIMUTH': 42.81637889,
#    'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#    'DATE_ACQUIRED': '2021-08-29',
#    'ELLIPSOID': 'WGS84',
#    'STATION_ID': 'LGN',
#    'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#    'ORIENTATION': 'NORTH_UP',
#    'WRS_ROW': 81,
#    'RADIANCE_MULT_BAND_9': 0.0023425,
#    'TARGET_WRS_ROW': 81,
#    'RADIANCE_MULT_BAND_7': 0.00050242,
#    'RADIANCE_MULT_BAND_8': 0.011085,
#    'IMAGE_QUALITY_TIRS': 9,
#    'TRUNCATION_OLI': 'UPPER',
#    'CLOUD_COVER': 14.17,
#    'GEOMETRIC_RMSE_VERIFY': 2.752,
#    'COLLECTION_CATEGORY': 'T1',
#    'GRID_CELL_SIZE_REFLECTIVE': 30,
#    'CLOUD_COVER_LAND': 14.17,
#    'GEOMETRIC_RMSE_MODEL': 5.969,
#    'COLLECTION_NUMBER': 2,
#    'IMAGE_QUALITY_OLI': 9,
#    'LANDSAT_SCENE_ID': 'LC80920812021241LGN00',
#    'WRS_PATH': 92,
#    'PANCHROMATIC_SAMPLES': 15541,
#    'PANCHROMATIC_LINES': 15681,
#    'GEOMETRIC_RMSE_MODEL_Y': 4.449,
#    'REFLECTIVE_LINES': 7841,
#    'GEOMETRIC_RMSE_MODEL_X': 3.979,
#    'system:index': '2021-08-29',
#    'DATA_SOURCE_ELEVATION': 'GLS2000',
#    'REFLECTANCE_ADD_BAND_1': -0.1,
#    'REFLECTANCE_ADD_BAND_2': -0.1,
#    'DATUM': 'WGS84',
#    'REFLECTANCE_ADD_BAND_3': -0.1,
#    'REFLECTANCE_ADD_BAND_4': -0.1,
#    'REFLECTANCE_ADD_BAND_5': -0.1,
#    'REFLECTANCE_ADD_BAND_6': -0.1,
#    'REFLECTANCE_ADD_BAND_7': -0.1,
#    'REFLECTANCE_ADD_BAND_8': -0.1,
#    'GROUND_CONTROL_POINTS_VERSION': 5,
#    'UTM_ZONE': 55,
#    'LANDSAT_PRODUCT_ID': 'LC08_L1TP_092081_20210829_20210901_02_T1',
#    'REFLECTANCE_ADD_BAND_9': -0.1,
#    'GRID_CELL_SIZE_PANCHROMATIC': 15,
#    'RADIANCE_ADD_BAND_4': -48.9737,
#    'REFLECTANCE_MULT_BAND_7': 2e-05,
#    'system:time_start': 1630195324244,
#    'RADIANCE_ADD_BAND_5': -29.96946,
#    'REFLECTANCE_MULT_BAND_6': 2e-05,
#    'RADIANCE_ADD_BAND_6': -7.45313,
#    'REFLECTANCE_MULT_BAND_9': 2e-05,
#    'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.5.0',
#    'RADIANCE_ADD_BAND_7': -2.5121,
#    'REFLECTANCE_MULT_BAND_8': 2e-05,
#    'RADIANCE_ADD_BAND_1': -61.547,
#    'RADIANCE_ADD_BAND_2': -63.02488,
#    'RADIANCE_ADD_BAND_3': -58.07689,
#    'REFLECTANCE_MULT_BAND_1': 2e-05,
#    'RADIANCE_ADD_BAND_8': -55.42475,
#    'REFLECTANCE_MULT_BAND_3': 2e-05,
#    'RADIANCE_ADD_BAND_9': -11.71275,
#    'REFLECTANCE_MULT_BAND_2': 2e-05,
#    'REFLECTANCE_MULT_BAND_5': 2e-05,
#    'REFLECTANCE_MULT_BAND_4': 2e-05,
#    'THERMAL_LINES': 7841,
#    'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#    'GRID_CELL_SIZE_THERMAL': 30,
#    'cloud_probability': 61.0467957216151,
#    'NADIR_OFFNADIR': 'NADIR',
#    'RADIANCE_ADD_BAND_11': 0.1,
#    'REQUEST_ID': 'P7010180acqva_00011',
#    'EARTH_SUN_DISTANCE': 1.0099572,
#    'TIRS_SSM_MODEL': 'FINAL',
#    'SCENE_CENTER_TIME': '00:01:40.2940530Z',
#    'SUN_ELEVATION': 39.87211822,
#    'RADIANCE_ADD_BAND_10': 0.1,
#    'ROLL_ANGLE': 0,
#    'DATE_PRODUCT_GENERATED': 1630518856000,
#    'K1_CONSTANT_BAND_10': 774.8853,
#    'SATURATION_BAND_1': 'N',
#    'SATURATION_BAND_2': 'N',
#    'SATURATION_BAND_3': 'N',
#    'SATURATION_BAND_4': 'N',
#    'SATURATION_BAND_5': 'N',
#    'MAP_PROJECTION': 'UTM',
#    'SATURATION_BAND_6': 'N',
#    'SENSOR_ID': 'OLI_TIRS',
#    'SATURATION_BAND_7': 'Y',
#    'K1_CONSTANT_BAND_11': 480.8883,
#    'SATURATION_BAND_8': 'N',
#    'SATURATION_BAND_9': 'N',
#    'TARGET_WRS_PATH': 92,
#    'PROCESSING_LEVEL': 'L1TP',
#    'RADIANCE_MULT_BAND_11': 0.0003342,
#    'RADIANCE_MULT_BAND_10': 0.0003342,
#    'GROUND_CONTROL_POINTS_MODEL': 616,
#    'SPACECRAFT_ID': 'LANDSAT_8',
#    'THERMAL_SAMPLES': 7771,
#    'GROUND_CONTROL_POINTS_VERIFY': 241,
#    'RADIANCE_MULT_BAND_5': 0.0059939,
#    'RADIANCE_MULT_BAND_6': 0.0014906,
#    'RADIANCE_MULT_BAND_3': 0.011615,
#    'RADIANCE_MULT_BAND_4': 0.0097947,
#    'RADIANCE_MULT_BAND_1': 0.012309}},
#  {'type': 'Image',
#   'bands': [{'id': 'B1',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B2',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B3',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B4',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B5',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B6',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B7',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B9',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B10',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B11',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'QA_PIXEL',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'probability',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]}],
#   'id': '2021-08-04',
#   'properties': {'RADIANCE_MULT_BAND_2': 0.012489,
#    'WRS_TYPE': 2,
#    'K2_CONSTANT_BAND_11': 1201.1442,
#    'valids': 0.015602829594730238,
#    'K2_CONSTANT_BAND_10': 1321.0789,
#    'REFLECTIVE_SAMPLES': 7701,
#    'SUN_AZIMUTH': 38.46054165,
#    'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#    'DATE_ACQUIRED': '2021-08-04',
#    'ELLIPSOID': 'WGS84',
#    'STATION_ID': 'LGN',
#    'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#    'ORIENTATION': 'NORTH_UP',
#    'WRS_ROW': 81,
#    'RADIANCE_MULT_BAND_9': 0.0023211,
#    'TARGET_WRS_ROW': 81,
#    'RADIANCE_MULT_BAND_7': 0.00049781,
#    'RADIANCE_MULT_BAND_8': 0.010983,
#    'IMAGE_QUALITY_TIRS': 9,
#    'TRUNCATION_OLI': 'UPPER',
#    'CLOUD_COVER': 1.96,
#    'GEOMETRIC_RMSE_VERIFY': 2.732,
#    'COLLECTION_CATEGORY': 'T1',
#    'GRID_CELL_SIZE_REFLECTIVE': 30,
#    'CLOUD_COVER_LAND': 1.96,
#    'GEOMETRIC_RMSE_MODEL': 5.175,
#    'COLLECTION_NUMBER': 2,
#    'IMAGE_QUALITY_OLI': 9,
#    'LANDSAT_SCENE_ID': 'LC80930812021216LGN00',
#    'WRS_PATH': 93,
#    'PANCHROMATIC_SAMPLES': 15401,
#    'PANCHROMATIC_LINES': 15541,
#    'GEOMETRIC_RMSE_MODEL_Y': 3.692,
#    'REFLECTIVE_LINES': 7771,
#    'GEOMETRIC_RMSE_MODEL_X': 3.626,
#    'system:index': '2021-08-04',
#    'DATA_SOURCE_ELEVATION': 'GLS2000',
#    'REFLECTANCE_ADD_BAND_1': -0.1,
#    'REFLECTANCE_ADD_BAND_2': -0.1,
#    'DATUM': 'WGS84',
#    'REFLECTANCE_ADD_BAND_3': -0.1,
#    'REFLECTANCE_ADD_BAND_4': -0.1,
#    'REFLECTANCE_ADD_BAND_5': -0.1,
#    'REFLECTANCE_ADD_BAND_6': -0.1,
#    'REFLECTANCE_ADD_BAND_7': -0.1,
#    'REFLECTANCE_ADD_BAND_8': -0.1,
#    'GROUND_CONTROL_POINTS_VERSION': 5,
#    'UTM_ZONE': 55,
#    'LANDSAT_PRODUCT_ID': 'LC08_L1TP_093081_20210804_20210811_02_T1',
#    'REFLECTANCE_ADD_BAND_9': -0.1,
#    'GRID_CELL_SIZE_PANCHROMATIC': 15,
#    'RADIANCE_ADD_BAND_4': -48.52445,
#    'REFLECTANCE_MULT_BAND_7': 2e-05,
#    'system:time_start': 1628035675183,
#    'RADIANCE_ADD_BAND_5': -29.69455,
#    'REFLECTANCE_MULT_BAND_6': 2e-05,
#    'RADIANCE_ADD_BAND_6': -7.38476,
#    'REFLECTANCE_MULT_BAND_9': 2e-05,
#    'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.5.0',
#    'RADIANCE_ADD_BAND_7': -2.48906,
#    'REFLECTANCE_MULT_BAND_8': 2e-05,
#    'RADIANCE_ADD_BAND_1': -60.98241,
#    'RADIANCE_ADD_BAND_2': -62.44673,
#    'RADIANCE_ADD_BAND_3': -57.54413,
#    'REFLECTANCE_MULT_BAND_1': 2e-05,
#    'RADIANCE_ADD_BAND_8': -54.91633,
#    'REFLECTANCE_MULT_BAND_3': 2e-05,
#    'RADIANCE_ADD_BAND_9': -11.6053,
#    'REFLECTANCE_MULT_BAND_2': 2e-05,
#    'REFLECTANCE_MULT_BAND_5': 2e-05,
#    'REFLECTANCE_MULT_BAND_4': 2e-05,
#    'THERMAL_LINES': 7771,
#    'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#    'GRID_CELL_SIZE_THERMAL': 30,
#    'cloud_probability': 0.042284116096153575,
#    'NADIR_OFFNADIR': 'NADIR',
#    'RADIANCE_ADD_BAND_11': 0.1,
#    'REQUEST_ID': 'P700xssv9iagt_00011',
#    'EARTH_SUN_DISTANCE': 1.0146216,
#    'TIRS_SSM_MODEL': 'FINAL',
#    'SCENE_CENTER_TIME': '00:07:43.2084169Z',
#    'SUN_ELEVATION': 32.69840701,
#    'RADIANCE_ADD_BAND_10': 0.1,
#    'ROLL_ANGLE': -0.001,
#    'DATE_PRODUCT_GENERATED': 1628661033000,
#    'K1_CONSTANT_BAND_10': 774.8853,
#    'SATURATION_BAND_1': 'N',
#    'SATURATION_BAND_2': 'N',
#    'SATURATION_BAND_3': 'N',
#    'SATURATION_BAND_4': 'N',
#    'SATURATION_BAND_5': 'N',
#    'MAP_PROJECTION': 'UTM',
#    'SATURATION_BAND_6': 'N',
#    'SENSOR_ID': 'OLI_TIRS',
#    'SATURATION_BAND_7': 'Y',
#    'K1_CONSTANT_BAND_11': 480.8883,
#    'SATURATION_BAND_8': 'N',
#    'SATURATION_BAND_9': 'N',
#    'TARGET_WRS_PATH': 93,
#    'PROCESSING_LEVEL': 'L1TP',
#    'RADIANCE_MULT_BAND_11': 0.0003342,
#    'RADIANCE_MULT_BAND_10': 0.0003342,
#    'GROUND_CONTROL_POINTS_MODEL': 961,
#    'SPACECRAFT_ID': 'LANDSAT_8',
#    'THERMAL_SAMPLES': 7701,
#    'GROUND_CONTROL_POINTS_VERIFY': 333,
#    'RADIANCE_MULT_BAND_5': 0.0059389,
#    'RADIANCE_MULT_BAND_6': 0.001477,
#    'RADIANCE_MULT_BAND_3': 0.011509,
#    'RADIANCE_MULT_BAND_4': 0.0097049,
#    'RADIANCE_MULT_BAND_1': 0.012196}},
#  {'type': 'Image',
#   'bands': [{'id': 'B1',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B2',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B3',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B4',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B5',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B6',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B7',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B9',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B10',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'B11',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'QA_PIXEL',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]},
#    {'id': 'probability',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'crs': 'EPSG:4326',
#     'crs_transform': [1, 0, 0, 0, 1, 0]}],
#   'id': '2021-08-20',
#   'properties': {'RADIANCE_MULT_BAND_2': 0.012557,
#    'WRS_TYPE': 2,
#    'K2_CONSTANT_BAND_11': 1201.1442,
#    'valids': 0.015538653340168738,
#    'K2_CONSTANT_BAND_10': 1321.0789,
#    'REFLECTIVE_SAMPLES': 7701,
#    'SUN_AZIMUTH': 41.13383743,
#    'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS',
#    'DATE_ACQUIRED': '2021-08-20',
#    'ELLIPSOID': 'WGS84',
#    'STATION_ID': 'LGN',
#    'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#    'ORIENTATION': 'NORTH_UP',
#    'WRS_ROW': 81,
#    'RADIANCE_MULT_BAND_9': 0.0023337,
#    'TARGET_WRS_ROW': 81,
#    'RADIANCE_MULT_BAND_7': 0.00050053,
#    'RADIANCE_MULT_BAND_8': 0.011043,
#    'IMAGE_QUALITY_TIRS': 9,
#    'TRUNCATION_OLI': 'UPPER',
#    'CLOUD_COVER': 0.01,
#    'GEOMETRIC_RMSE_VERIFY': 2.536,
#    'COLLECTION_CATEGORY': 'T1',
#    'GRID_CELL_SIZE_REFLECTIVE': 30,
#    'CLOUD_COVER_LAND': 0.01,
#    'GEOMETRIC_RMSE_MODEL': 4.886,
#    'COLLECTION_NUMBER': 2,
#    'IMAGE_QUALITY_OLI': 9,
#    'LANDSAT_SCENE_ID': 'LC80930812021232LGN00',
#    'WRS_PATH': 93,
#    'PANCHROMATIC_SAMPLES': 15401,
#    'PANCHROMATIC_LINES': 15521,
#    'GEOMETRIC_RMSE_MODEL_Y': 3.456,
#    'REFLECTIVE_LINES': 7761,
#    'GEOMETRIC_RMSE_MODEL_X': 3.454,
#    'system:index': '2021-08-20',
#    'DATA_SOURCE_ELEVATION': 'GLS2000',
#    'REFLECTANCE_ADD_BAND_1': -0.1,
#    'REFLECTANCE_ADD_BAND_2': -0.1,
#    'DATUM': 'WGS84',
#    'REFLECTANCE_ADD_BAND_3': -0.1,
#    'REFLECTANCE_ADD_BAND_4': -0.1,
#    'REFLECTANCE_ADD_BAND_5': -0.1,
#    'REFLECTANCE_ADD_BAND_6': -0.1,
#    'REFLECTANCE_ADD_BAND_7': -0.1,
#    'REFLECTANCE_ADD_BAND_8': -0.1,
#    'GROUND_CONTROL_POINTS_VERSION': 5,
#    'UTM_ZONE': 55,
#    'LANDSAT_PRODUCT_ID': 'LC08_L1TP_093081_20210820_20210827_02_T1',
#    'REFLECTANCE_ADD_BAND_9': -0.1,
#    'GRID_CELL_SIZE_PANCHROMATIC': 15,
#    'RADIANCE_ADD_BAND_4': -48.78914,
#    'REFLECTANCE_MULT_BAND_7': 2e-05,
#    'system:time_start': 1629418080657,
#    'RADIANCE_ADD_BAND_5': -29.85652,
#    'REFLECTANCE_MULT_BAND_6': 2e-05,
#    'RADIANCE_ADD_BAND_6': -7.42505,
#    'REFLECTANCE_MULT_BAND_9': 2e-05,
#    'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.5.0',
#    'RADIANCE_ADD_BAND_7': -2.50264,
#    'REFLECTANCE_MULT_BAND_8': 2e-05,
#    'RADIANCE_ADD_BAND_1': -61.31506,
#    'RADIANCE_ADD_BAND_2': -62.78737,
#    'RADIANCE_ADD_BAND_3': -57.85802,
#    'REFLECTANCE_MULT_BAND_1': 2e-05,
#    'RADIANCE_ADD_BAND_8': -55.21588,
#    'REFLECTANCE_MULT_BAND_3': 2e-05,
#    'RADIANCE_ADD_BAND_9': -11.66861,
#    'REFLECTANCE_MULT_BAND_2': 2e-05,
#    'REFLECTANCE_MULT_BAND_5': 2e-05,
#    'REFLECTANCE_MULT_BAND_4': 2e-05,
#    'THERMAL_LINES': 7761,
#    'TIRS_SSM_POSITION_STATUS': 'ESTIMATED',
#    'GRID_CELL_SIZE_THERMAL': 30,
#    'cloud_probability': 0,
#    'NADIR_OFFNADIR': 'NADIR',
#    'RADIANCE_ADD_BAND_11': 0.1,
#    'REQUEST_ID': 'P700ypo5dmo28_00011',
#    'EARTH_SUN_DISTANCE': 1.0118657,
#    'TIRS_SSM_MODEL': 'FINAL',
#    'SCENE_CENTER_TIME': '00:07:48.6820229Z',
#    'SUN_ELEVATION': 37.01522603,
#    'RADIANCE_ADD_BAND_10': 0.1,
#    'ROLL_ANGLE': -0.001,
#    'DATE_PRODUCT_GENERATED': 1630056505000,
#    'K1_CONSTANT_BAND_10': 774.8853,
#    'SATURATION_BAND_1': 'N',
#    'SATURATION_BAND_2': 'N',
#    'SATURATION_BAND_3': 'N',
#    'SATURATION_BAND_4': 'N',
#    'SATURATION_BAND_5': 'N',
#    'MAP_PROJECTION': 'UTM',
#    'SATURATION_BAND_6': 'Y',
#    'SENSOR_ID': 'OLI_TIRS',
#    'SATURATION_BAND_7': 'Y',
#    'K1_CONSTANT_BAND_11': 480.8883,
#    'SATURATION_BAND_8': 'N',
#    'SATURATION_BAND_9': 'N',
#    'TARGET_WRS_PATH': 93,
#    'PROCESSING_LEVEL': 'L1TP',
#    'RADIANCE_MULT_BAND_11': 0.0003342,
#    'RADIANCE_MULT_BAND_10': 0.0003342,
#    'GROUND_CONTROL_POINTS_MODEL': 986,
#    'SPACECRAFT_ID': 'LANDSAT_8',
#    'THERMAL_SAMPLES': 7701,
#    'GROUND_CONTROL_POINTS_VERIFY': 320,
#    'RADIANCE_MULT_BAND_5': 0.0059713,
#    'RADIANCE_MULT_BAND_6': 0.001485,
#    'RADIANCE_MULT_BAND_3': 0.011572,
#    'RADIANCE_MULT_BAND_4': 0.0097578,
#    'RADIANCE_MULT_BAND_1': 0.012263}}]

# %% [markdown]
# # Checking the shapefile data type

# %%
import shutil

# %%
extract= shutil.unpack_archive('Declarations_19722_Merge.zip')

# %%
test= gpd.read_file('Declarations_unzip/Declarations_19722_Merge.shp')

# %%
type(test)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
type(test['geometry'])
# Out:
# geopandas.geoseries.GeoSeries

# %%
type(test['geometry'][37])
# Out:
# shapely.geometry.multipolygon.MultiPolygon

# %% [markdown]
# # Putting useful information into a dataframe

# %% [markdown]
# * CLOUD_COVER
# * polygon
# * satellite image ID associated with the polygon
# * date associated with the specific satellite image
#
#
# We need to find out what other useful information is in the properties of the imageCollection

# %% [markdown]
# Checking the number of polygons in `js` which comes from `sydney_aoi`

# %%
len(js['features'])
# Out:
# 481

# %% [markdown]
# Can also be done with

# %%
len(sydney_aoi)
# Out:
# 481

# %% [markdown]
# Checking the `myDict['features'][0].get('properties')` dictionary, some interesting properties to explore are:
# * CLOUD_COVER
# * cloud_probability
# * DATE_ACQUIRED
# * 'system:index'
#
# this is another date, one day after DATE_ACQUIRED.
# * CLOUD_COVER_LAND
# * COLLECTION_NUMBER
#
# Checking the `myDict['features'][0].get('id')` dictionary has a date that is one day after DATE_acquired.

# %%
cloudScore_landsat
# Out:
# array([3.480e+00, 1.097e+01, 4.043e+01, 7.651e+01, 3.200e-01, 5.000e-02,
#        5.469e+01, 1.080e+01, 2.000e-02, 1.417e+01, 1.960e+00, 1.000e-02])

# %% [raw]
# myDict['features']

# %% [raw]
# myDict['features'][0].get('properties')

# %% [markdown]
# # Extracting properties for individual polygons from original AOI

# %%
def get_imageCollections(bounds: ee.geometry.Geometry, dates: tuple): # returns imageCollection

    get_landsat_collection = ee_download.get_landsat_collection
    landsat_imgs = get_landsat_collection(date_start=dates[0], date_end=dates[1] , bounds= bounds)

    get_s2_collection = ee_download.get_s2_collection
    s2_imgs = get_s2_collection(date_start=dates[0], date_end=dates[1] , bounds= bounds)
    
    return landsat_imgs, s2_imgs

# %%
def get_datetime(date_range: tuple): # function returns a tuple containing datetime
    datetime_start= datetime.strptime(date_range[0], '%d/%m/%y')
    datetime_end= datetime.strptime(date_range[1], '%d/%m/%y')
    
    start_year = datetime_start.year
    end_year = datetime_end.year
    
    return datetime_start, datetime_end, start_year, end_year

# %%
def read_aoi(my_gpd_aoi:str):
    my_aoi = gpd.read_file(my_gpd_aoi)
    
    aoi_codes = my_aoi['aoi_code']
    js = json.loads(my_aoi.to_json()) # convertin gthe aoi to a json and getting the 
    bounds = ee.Geometry(ee.FeatureCollection(js).geometry())
    
    return bounds, aoi_codes

# %%
def extract_properties(landsat_imgs, s2_imgs, init_bounds, aoi_code):
    
    coordinates = init_bounds['coordinates']
    
    landsat_dict = landsat_imgs.getInfo()
    s2_dict = s2_imgs.getInfo()
    
    n_landsat = len(landsat_dict['features'])
    print('Landsat images:', n_landsat)
    n_s2 = len(s2_dict['features'])
    print('s2 images:', n_s2)
    
    n_total = n_landsat + n_s2 
    
    properties_df = pd.DataFrame(index=np.arange(0, n_total), columns=['id', 'source', 'cloud_cover', 'percentage_valid_pixels', 'coordinates', 'aoi_code']) 
    
    
    for i in range(n_landsat):
        properties_df['id'][i] = landsat_dict['features'][i].get('id')
        properties_df['source'][i] = 'landsat'
        properties_df['cloud_cover'][i] = landsat_dict['features'][i].get('properties')['CLOUD_COVER']
        properties_df['percentage_valid_pixels'][i] = landsat_dict['features'][i].get('properties')['valids'] 
        properties_df['coordinates'][i] = coordinates
        properties_df['aoi_code'][i] = aoi_code
        #find area/co-ordinates associated with each image
        
    for i in range(n_s2):
        j = i + n_landsat
        
        properties_df['id'][j] = s2_dict['features'][i].get('id')
        properties_df['source'][j] = 's2'
        properties_df['cloud_cover'][j] = s2_dict['features'][i].get('properties')['CLOUD_COVERAGE_ASSESSMENT']
        properties_df['percentage_valid_pixels'][j] = s2_dict['features'][i].get('properties')['valids'] 
        properties_df['coordinates'][j] = coordinates
        properties_df['aoi_code'][j] = aoi_code
        #find area/co-ordinates associated with each image
    
    return properties_df

# %%
test_dates = ('02/08/21', '03/09/21')

test_datetime = get_datetime(test_dates)

# %%
sydney_aoi, sydney_aoi_codes = read_aoi('2022-07-21_aois.geojson')

sydney_aoi_codes
# Out:
# 0        AOI01
# 1        AOI01
# 2        AOI02
# 3        AOI02
# 4      AOI0289
#         ...
# 476      AOI97
# 477      AOI98
# 478      AOI98
# 479      AOI99
# 480      AOI99
# Name: aoi_code, Length: 481, dtype: object

# %%
sydney_aoi_all = sydney_aoi.getInfo()['coordinates']

sydney_aoi_all[0]
# Out:
# [[[147.09959654580408, -31.244618412374592],
#   [147.30959654580408, -31.244618412374592],
#   [147.30959654580408, -31.03461841237459],
#   [147.09959654580408, -31.03461841237459],
#   [147.09959654580408, -31.244618412374592]]]

# %%
len(sydney_aoi_all)
# Out:
# 263

# %%
sydney_aoi_poly = ee.Geometry.Polygon(sydney_aoi_all[0])

type(sydney_aoi_poly)
# Out:
# ee.geometry.Geometry

# %%
len(sydney_aoi_all)
# Out:
# 263

# %%
poly_landsat, poly_s2 = get_imageCollections(sydney_aoi_poly, test_datetime)

# %%
test_poly_df = extract_properties(poly_landsat, poly_s2, sydney_aoi_poly, sydney_aoi_codes[0])
# Out:
# Landsat images: 4
# s2 images: 13

# %%
test_poly_df
# Out:
#             id   source cloud_cover percentage_valid_pixels  \
# 0   2021-08-13  landsat        0.02                       1
# 1   2021-08-29  landsat       14.17                       1
# 2   2021-08-04  landsat        1.96                0.279306
# 3   2021-08-20  landsat        0.01                0.276128
# 4   2021-08-03       s2      3.0108                       1
# 5   2021-08-05       s2      40.112                       1
# 6   2021-08-08       s2      2.0378                       1
# 7   2021-08-10       s2           0                       1
# 8   2021-08-13       s2      0.0281                       1
# 9   2021-08-15       s2      5.4465                       1
# 10  2021-08-18       s2      0.2876                       1
# 11  2021-08-20       s2      0.6071                       1
# 12  2021-08-23       s2     33.5172                       1
# 13  2021-08-25       s2      0.1036                       1
# 14  2021-08-28       s2           0                       1
# 15  2021-08-30       s2     97.7998                       1
# 16  2021-09-02       s2           0                       1
#
#                                           coordinates aoi_code
# 0   [[[147.09959654580408, -31.244618412374592], [...    AOI01
# 1   [[[147.09959654580408, -31.244618412374592], [...    AOI01
# 2   [[[147.09959654580408, -31.244618412374592], [...    AOI01
# 3   [[[147.09959654580408, -31.244618412374592], [...    AOI01
# 4   [[[147.09959654580408, -31.244618412374592], [...    AOI01
# 5   [[[147.09959654580408, -31.244618412374592], [...    AOI01
# 6   [[[147.09959654580408, -31.244618412374592], [...    AOI01
# 7   [[[147.09959654580408, -31.244618412374592], [...    AOI01
# 8   [[[147.09959654580408, -31.244618412374592], [...    AOI01
# 9   [[[147.09959654580408, -31.244618412374592], [...    AOI01
# 10  [[[147.09959654580408, -31.244618412374592], [...    AOI01
# 11  [[[147.09959654580408, -31.244618412374592], [...    AOI01
# 12  [[[147.09959654580408, -31.244618412374592], [...    AOI01
# 13  [[[147.09959654580408, -31.244618412374592], [...    AOI01
# 14  [[[147.09959654580408, -31.244618412374592], [...    AOI01
# 15  [[[147.09959654580408, -31.244618412374592], [...    AOI01
# 16  [[[147.09959654580408, -31.244618412374592], [...    AOI01

# %%
test_poly_df['coordinates'][0]
# Out:
# [[[147.09959654580408, -31.244618412374592],
#   [147.30959654580408, -31.244618412374592],
#   [147.30959654580408, -31.03461841237459],
#   [147.09959654580408, -31.03461841237459],
#   [147.09959654580408, -31.244618412374592]]]

# %%
test_poly_df.shape
# Out:
# (17, 6)

# %% [markdown]
# **QUESTION** Previously we had 12 images for landsat and 26 images for s2, is the decrease we see above due to only selecting a single AOI from `sydney_aoi_codes`?

# %% [markdown]
# `test_poly_df` Now has the properties from the iamges for a single polygon of an AOI, being from `sydney_aoi_all[0]`. We want to link all the AOI codes to each polygon.
#
# It seems like for each polygon we need to check each image and associate the AOI to that polygon.

# %% [markdown]
# # Getting the images for multiple polygons

# %%
type(sydney_aoi_poly)
# Out:
# ee.geometry.Geometry

# %% [markdown]
# Getting the first 20 polygons instead of all 263 (long processing times when getting the imageCollection. If you run on all 263 polygons, takes about 10 minutes.

# %%
sydney_aoi, sydney_aoi_codes = read_aoi('2022-07-21_aois.geojson')

# sydney_aoi_codes

# %%
sydney_aoi_all = sydney_aoi.getInfo()['coordinates']

sydney_aoi_all

# %%
sydney_aoi_poly = []
for i in range(len(sydney_aoi_all[0:20])):
    sydney_aoi_poly = np.append(sydney_aoi_poly, ee.Geometry.Polygon(sydney_aoi_all[i]))
    
type(sydney_aoi_poly)
# Out:
# numpy.ndarray

# %%
sydney_aoi_poly[0]['coordinates']
# Out:
# [[[147.09959654580408, -31.244618412374592],
#   [147.30959654580408, -31.244618412374592],
#   [147.30959654580408, -31.03461841237459],
#   [147.09959654580408, -31.03461841237459],
#   [147.09959654580408, -31.244618412374592]]]

# %% [markdown]
# Getting the first 20 codes to match the first 20 polygons

# %%
sydney_aoi_codes = sydney_aoi_codes[0:20]

# %%
len(sydney_aoi_poly)
# Out:
# 20

# %%
def get_imageCollections(bounds: np.ndarray, dates: tuple): # returns imageCollection

    get_landsat_collection = ee_download.get_landsat_collection
    get_s2_collection = ee_download.get_s2_collection
    
    landsat_imgs = []
    s2_imgs = []
    
    for i in range(len(sydney_aoi_poly)):
        landsat_imgs = np.append(landsat_imgs, get_landsat_collection(date_start=dates[0], date_end=dates[1] , bounds= bounds[i]))
        s2_imgs = np.append(s2_imgs, get_s2_collection(date_start=dates[0], date_end=dates[1] , bounds= bounds[i]))

    return landsat_imgs, s2_imgs

# %%
poly_landsat, poly_s2 = get_imageCollections(sydney_aoi_poly, test_datetime)

# %%
len(poly_landsat[0].getInfo()['features'])
# Out:
# 4

# %% [markdown]
# Checking how many images are in each of the firs 20 polygons

# %%
for i in range(len(poly_landsat)):
    print(len(poly_landsat[i].getInfo()['features']))
# Out:
# 4
# 4
# 2
# 2
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4

# %%
len(sydney_aoi_poly)
# Out:
# 20

# %%
sydney_aoi_poly[0]['coordinates']
# Out:
# [[[147.09959654580408, -31.244618412374592],
#   [147.30959654580408, -31.244618412374592],
#   [147.30959654580408, -31.03461841237459],
#   [147.09959654580408, -31.03461841237459],
#   [147.09959654580408, -31.244618412374592]]]

# %%
landsat_coordinates = [[] for _ in range(len(poly_landsat))] # creating number of lists to match the number of polygons so that each polygon will have it's coordinates
n_landsat = []

for i in range(len(poly_landsat)):
    landsat_coordinates[i] = sydney_aoi_poly[i]['coordinates']

    n_landsat = np.append(n_landsat, len(poly_landsat[i].getInfo()['features'])) # Of the 20 indices, there will be the number of images in each.

# %% [markdown]
# Trying to make a DF that isn't nested. Creating the DF comes later, first let's try to make lists that will be used to populate the DF.

# %%
id_list = []
cloudCover_list = []
validPixels_list = []
# coordinates_list = []
# aoi_list = []
source_list = ['landsat']*np.int(n_landsat.sum()) # creating a list the size of the total number of images of all the polygons

for i in range(len(poly_landsat)): # Iterating through all the polygons
    
    for k in range(np.int(n_landsat[i])): # Iterating through all the images of each polygon
        
        id_list = np.append(id_list, poly_landsat[i].getInfo()['features'][k].get('id'))
        cloudCover_list = np.append(cloudCover_list, poly_landsat[i].getInfo()['features'][k].get('properties')['CLOUD_COVER'])
        validPixels_list = np.append(validPixels_list, poly_landsat[i].getInfo()['features'][k].get('properties')['valids'])
        # coordinates_list = landsat_coordinates[i]
        # aoi_list = sydney_aoi_codes[i]

# %% [markdown]
# Having issues with coordinates and aoi, commented them out and will work on them in a separate cell.

# %%
len(landsat_coordinates)
# Out:
# 20

# %%
landsat_coordinates[0]
# Out:
# [[[147.09959654580408, -31.244618412374592],
#   [147.30959654580408, -31.244618412374592],
#   [147.30959654580408, -31.03461841237459],
#   [147.09959654580408, -31.03461841237459],
#   [147.09959654580408, -31.244618412374592]]]

# %%
coordinates_list = [] # creating number of lists to match the number of polygons so that each polygon will have it's coordinates

aoi_list = []

for i in range(len(poly_landsat)): # Iterating through all the polygons
    
    for k in range(len(poly_landsat[i].getInfo()['features'])): # Iterating through all the images of each polygon
        
        print(k)
        
        aoi_list = np.append(aoi_list, sydney_aoi_codes[i])
        
        index_coord = landsat_coordinates[i]
        
        print(index_coord)

        coordinates_list.extend(index_coord)
# Out:
# 0
# [[[147.09959654580408, -31.244618412374592], [147.30959654580408, -31.244618412374592], [147.30959654580408, -31.03461841237459], [147.09959654580408, -31.03461841237459], [147.09959654580408, -31.244618412374592]]]
# 1
# [[[147.09959654580408, -31.244618412374592], [147.30959654580408, -31.244618412374592], [147.30959654580408, -31.03461841237459], [147.09959654580408, -31.03461841237459], [147.09959654580408, -31.244618412374592]]]
# 2
# [[[147.09959654580408, -31.244618412374592], [147.30959654580408, -31.244618412374592], [147.30959654580408, -31.03461841237459], [147.09959654580408, -31.03461841237459], [147.09959654580408, -31.244618412374592]]]
# 3
# [[[147.09959654580408, -31.244618412374592], [147.30959654580408, -31.244618412374592], [147.30959654580408, -31.03461841237459], [147.09959654580408, -31.03461841237459], [147.09959654580408, -31.244618412374592]]]
# 0
# [[[147.09959654580408, -31.04461841237459], [147.30959654580408, -31.04461841237459], [147.30959654580408, -30.83461841237459], [147.09959654580408, -30.83461841237459], [147.09959654580408, -31.04461841237459]]]
# 1
# [[[147.09959654580408, -31.04461841237459], [147.30959654580408, -31.04461841237459], [147.30959654580408, -30.83461841237459], [147.09959654580408, -30.83461841237459], [147.09959654580408, -31.04461841237459]]]
# 2
# [[[147.09959654580408, -31.04461841237459], [147.30959654580408, -31.04461841237459], [147.30959654580408, -30.83461841237459], [147.09959654580408, -30.83461841237459], [147.09959654580408, -31.04461841237459]]]
# 3
# [[[147.09959654580408, -31.04461841237459], [147.30959654580408, -31.04461841237459], [147.30959654580408, -30.83461841237459], [147.09959654580408, -30.83461841237459], [147.09959654580408, -31.04461841237459]]]
# 0
# [[[147.4996031608572, -32.44460560526437], [147.7096031608572, -32.44460560526437], [147.7096031608572, -32.23460560526437], [147.4996031608572, -32.23460560526437], [147.4996031608572, -32.44460560526437]]]
# 1
# [[[148.29960316085715, -32.24460560526437], [148.50960316085715, -32.24460560526437], [148.50960316085715, -32.03460560526437], [148.29960316085715, -32.03460560526437], [148.29960316085715, -32.24460560526437]]]
# 0
# [[[148.29960316085715, -32.044605605264366], [148.50960316085715, -32.044605605264366], [148.50960316085715, -31.834605605264365], [148.29960316085715, -31.834605605264365], [148.29960316085715, -32.044605605264366]]]
# 1
# [[[148.29960316085715, -32.044605605264366], [148.50960316085715, -32.044605605264366], [148.50960316085715, -31.834605605264365], [148.29960316085715, -31.834605605264365], [148.29960316085715, -32.044605605264366]]]
# 2
# [[[148.29960316085715, -32.044605605264366], [148.50960316085715, -32.044605605264366], [148.50960316085715, -31.834605605264365], [148.29960316085715, -31.834605605264365], [148.29960316085715, -32.044605605264366]]]
# 3
# [[[148.29960316085715, -32.044605605264366], [148.50960316085715, -32.044605605264366], [148.50960316085715, -31.834605605264365], [148.29960316085715, -31.834605605264365], [148.29960316085715, -32.044605605264366]]]

# %%
len(coordinates_list)
# Out:
# 76

# %%
type(coordinates_list[0])
# Out:
# list

# %% [markdown]
# Managed to get the aoi list, but the coordinates list is having issues. For every polygon, the array of coordinates needs to be duplicated to the number of images that are in the polygon.

# %%
landsat_df = gpd.GeoDataFrame({'id':id_list, 'cloud_cover':cloudCover_list, 'source': source_list, 'aoi_code': aoi_list, 'percentage_valid_pixels': validPixels_list, 'geometry':coordinates_list})
landsat_df.head(10)
# Out:
#            id  cloud_cover   source aoi_code  percentage_valid_pixels  \
# 0  2021-08-13         0.02  landsat    AOI01                 1.000000
# 1  2021-08-29        14.17  landsat    AOI01                 1.000000
# 2  2021-08-04         1.96  landsat    AOI01                 0.279306
# 3  2021-08-20         0.01  landsat    AOI01                 0.276128
# 4  2021-08-13         0.02  landsat    AOI01                 1.000000
# 5  2021-08-29        14.17  landsat    AOI01                 1.000000
# 6  2021-08-04         1.96  landsat    AOI01                 0.521599
# 7  2021-08-20         0.01  landsat    AOI01                 0.518510
# 8  2021-08-13         2.36  landsat    AOI02                 1.000000
# 9  2021-08-29        56.97  landsat    AOI02                 1.000000
#
#                                             geometry
# 0  [[147.09959654580408, -31.244618412374592], [1...
# 1  [[147.09959654580408, -31.244618412374592], [1...
# 2  [[147.09959654580408, -31.244618412374592], [1...
# 3  [[147.09959654580408, -31.244618412374592], [1...
# 4  [[147.09959654580408, -31.04461841237459], [14...
# 5  [[147.09959654580408, -31.04461841237459], [14...
# 6  [[147.09959654580408, -31.04461841237459], [14...
# 7  [[147.09959654580408, -31.04461841237459], [14...
# 8  [[147.4996031608572, -32.44460560526437], [147...
# 9  [[147.4996031608572, -32.44460560526437], [147...

# %%
from shapely.geometry import Polygon

landsat_gdf['geometry'] = landsat_df['geometry'].apply(Polygon)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3674/4082496707.py in <module>
#       1 from shapely.geometry import Polygon
#       2
# ----> 3 landsat_gdf['geometry'] = landsat_df['geometry'].apply(Polygon)
#
# NameError: name 'landsat_gdf' is not defined

# %%
landsat_gdf

# %%
landsat_gdf = landsat_gdf.set_crs('EPSG:4326')

landsat_gdf.crs

# %%
# !pip install folium matplotlib mapclassify

# %%
landsat_gdf.explore()
